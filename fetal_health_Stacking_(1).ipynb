# %% [markdown]
# # Import Libraries and Load Data

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load dataset
df = pd.read_csv('/content/drive/MyDrive/fetal_health.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
#  8   mean_value_of_short_term_variability                    2126 non-null   float64
#  9   percentage_of_time_with_abnormal_long_term_variability  2126 non-null   float64
#  10  mean_value_of_long_term_variability                     2126 non-null   float64
#  11  histogram_width                                         2126 non-null   float64
#  12  histogram_min                                           2126 non-null   float64
#  13  histogram_max                                           2126 non-null   float64
#  14  histogram_number_of_peaks                               2126 non-null   float64
#  15  histogram_number_of_zeroes                              2126 non-null   float64
#  16  histogram_mode                                          2126 non-null   float64
#  17  histogram_mean                                          2126 non-null   float64
#  18  histogram_median                                        2126 non-null   float64
#  19  histogram_variance                                      2126 non-null   float64
#  20  histogram_tendency                                      2126 non-null   float64
#  21  fetal_health                                            2126 non-null   float64
# dtypes: float64(22)
# memory usage: 365.5 KB

# %%
df.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# std               0.002960              0.000057                  0.000590
# min               0.000000              0.000000                  0.000000
# 25%               0.000000              0.000000                  0.000000
# 50%               0.000000              0.000000                  0.000000
# 75%               0.003000              0.000000                  0.000000
# max               0.015000              0.001000                  0.005000
#
#        abnormal_short_term_variability  mean_value_of_short_term_variability  \
# count                      2126.000000                           2126.000000
# mean                         46.990122                              1.332785
# std                          17.192814                              0.883241
# min                          12.000000                              0.200000
# 25%                          32.000000                              0.700000
# 50%                          49.000000                              1.200000
# 75%                          61.000000                              1.700000
# max                          87.000000                              7.000000
#
#        percentage_of_time_with_abnormal_long_term_variability  ...  \
# count                                         2126.00000       ...
# mean                                             9.84666       ...
# std                                             18.39688       ...
# min                                              0.00000       ...
# 25%                                              0.00000       ...
# 50%                                              0.00000       ...
# 75%                                             11.00000       ...
# max                                             91.00000       ...
#
#        histogram_min  histogram_max  histogram_number_of_peaks  \
# count    2126.000000    2126.000000                2126.000000
# mean       93.579492     164.025400                   4.068203
# std        29.560212      17.944183                   2.949386
# min        50.000000     122.000000                   0.000000
# 25%        67.000000     152.000000                   2.000000
# 50%        93.000000     162.000000                   3.000000
# 75%       120.000000     174.000000                   6.000000
# max       159.000000     238.000000                  18.000000
#
#        histogram_number_of_zeroes  histogram_mode  histogram_mean  \
# count                 2126.000000     2126.000000     2126.000000
# mean                     0.323612      137.452023      134.610536
# std                      0.706059       16.381289       15.593596
# min                      0.000000       60.000000       73.000000
# 25%                      0.000000      129.000000      125.000000
# 50%                      0.000000      139.000000      136.000000
# 75%                      0.000000      148.000000      145.000000
# max                     10.000000      187.000000      182.000000
#
#        histogram_median  histogram_variance  histogram_tendency  fetal_health
# count       2126.000000         2126.000000         2126.000000   2126.000000
# mean         138.090310           18.808090            0.320320      1.304327
# std           14.466589           28.977636            0.610829      0.614377
# min           77.000000            0.000000           -1.000000      1.000000
# 25%          129.000000            2.000000            0.000000      1.000000
# 50%          139.000000            7.000000            0.000000      1.000000
# 75%          148.000000           24.000000            1.000000      1.000000
# max          186.000000          269.000000            1.000000      3.000000
#
# [8 rows x 22 columns]

# %%
df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
#Check for null Values
df.isna().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# histogram_mode                                            0
# histogram_mean                                            0
# histogram_median                                          0
# histogram_variance                                        0
# histogram_tendency                                        0
# fetal_health                                              0
# dtype: int64

# %%
# Check class distribution
print("\nClass Distribution:")
df['fetal_health'].value_counts()
# Out:
# Class Distribution:
# fetal_health
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: count, dtype: int64

# %%
# Correlation analysis to identify redundant features
import  seaborn as sns
corr_matrix = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
# Separate features and target
X = df.drop(columns=['fetal_health'])
y = df['fetal_health']

# %% [markdown]
#  # Feature Selection

# %%
# 1 Feature Importance Graph BEFORE RFE (All Features)
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X, y)
feature_importance = rf_model.feature_importances_
sorted_idx = np.argsort(feature_importance)[::-1]

plt.figure(figsize=(12, 6))
plt.bar(range(len(X.columns)), feature_importance[sorted_idx], align='center')
plt.xticks(range(len(X.columns)), X.columns[sorted_idx], rotation=90)
plt.xlabel('Feature Names')
plt.ylabel('Feature Importance Score')
plt.title('Feature Importance (Before RFE)')
plt.show()

# %%
# 2 Feature Selection Using RFE
rfe_selector = RFE(rf_model, n_features_to_select=10)
X_selected = rfe_selector.fit_transform(X, y)
selected_features = X.columns[rfe_selector.support_]

# 3 Feature Importance Graph AFTER RFE (Selected Features)
selected_importance = feature_importance[rfe_selector.support_]
sorted_idx_selected = np.argsort(selected_importance)[::-1]

plt.figure(figsize=(10, 6))
plt.bar(range(len(selected_features)), selected_importance[sorted_idx_selected], align='center')
plt.xticks(range(len(selected_features)), np.array(selected_features)[sorted_idx_selected], rotation=45)
plt.xlabel('Feature Names')
plt.ylabel('Feature Importance Score')
plt.title('Top 10 Important Features (After RFE)')
plt.show()

# %%
print(selected_features)
# Out:
# Index(['accelerations', 'prolongued_decelerations',
#        'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_mode', 'histogram_mean', 'histogram_median'],
#       dtype='object')

# %%
# 4 Apply SMOTE (Balancing the Classes)
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_selected, y)

# 5 Standardize the Data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# 6 Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# %%
import numpy as np
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts)))  # Check if classes are balanced

# %% [markdown]
# # Base Models

# %%
# Machine Learning Models

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier
import lightgbm as lgbm
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#  Logistic Regression
log_model = LogisticRegression()
log_model.fit(X_train, y_train)
y_pred_log = log_model.predict(X_test)

print("\n Logistic Regression Metrics")
print(classification_report(y_test, y_pred_log))
sns.heatmap(confusion_matrix(y_test, y_pred_log), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

# %%
# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)

print("\n KNN Metrics")
print(classification_report(y_test, y_pred_knn))
sns.heatmap(confusion_matrix(y_test, y_pred_knn), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - KNN")
plt.show()

# %%
#  Naïve Bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
y_pred_nb = nb_model.predict(X_test)

print("\n Naïve Bayes Metrics")
print(classification_report(y_test, y_pred_nb))
sns.heatmap(confusion_matrix(y_test, y_pred_nb), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Naïve Bayes")
plt.show()
# Out:
#  Naïve Bayes Metrics
#               precision    recall  f1-score   support
#
#          1.0       0.91      0.79      0.85       331
#          2.0       0.69      0.86      0.76       331
#          3.0       0.86      0.75      0.80       331
#
#     accuracy                           0.80       993
#    macro avg       0.82      0.80      0.80       993
# weighted avg       0.82      0.80      0.80       993

# %%
#  Support Vector Machine (SVM)
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)

print("\n SVM Metrics")
print(classification_report(y_test, y_pred_svm))
sns.heatmap(confusion_matrix(y_test, y_pred_svm), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - SVM")
plt.show()

# %%
#  Decision Tree
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

print("\n Decision Tree Metrics")
print(classification_report(y_test, y_pred_dt))
sns.heatmap(confusion_matrix(y_test, y_pred_dt), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Decision Tree")
plt.show()

# %% [markdown]
# # Ensemble Models

# %%
#  Random Forest (Bagging)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

print("\n Random Forest Metrics")
print(classification_report(y_test, y_pred_rf))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %%
#  Gradient Boosting
gb_model = GradientBoostingClassifier()
gb_model.fit(X_train, y_train)
y_pred_gb = gb_model.predict(X_test)

print("\n Gradient Boosting Metrics")
print(classification_report(y_test, y_pred_gb))
sns.heatmap(confusion_matrix(y_test, y_pred_gb), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Gradient Boosting")
plt.show()

# %%
#  AdaBoost Model
adaboost_model = AdaBoostClassifier(n_estimators=100, random_state=42)
adaboost_model.fit(X_train, y_train)
y_pred_adaboost = adaboost_model.predict(X_test)

print("\n AdaBoost Metrics")
print(classification_report(y_test, y_pred_adaboost))
sns.heatmap(confusion_matrix(y_test, y_pred_adaboost), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - AdaBoost")
plt.show()

# %%
#  LightGBM
lgb_model = lgbm.LGBMClassifier()
lgb_model.fit(X_train, y_train)
y_pred_lgb = lgb_model.predict(X_test)

print("\n LightGBM Metrics")
print(classification_report(y_test, y_pred_lgb))
sns.heatmap(confusion_matrix(y_test, y_pred_lgb), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - LightGBM")
plt.show()

# %%
# Voting Classifier (Majority Voting)
voting_model = VotingClassifier(estimators=[('rf', rf_model), ('lgb', lgb_model)], voting='hard')
voting_model.fit(X_train, y_train)
y_pred_voting = voting_model.predict(X_test)

print("\n Voting Classifier Metrics")
print(classification_report(y_test, y_pred_voting))
sns.heatmap(confusion_matrix(y_test, y_pred_voting), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Voting Classifier")
plt.show()

# %% [markdown]
# Model Comparison

# %%
# Collect model names and their accuracy scores
models = {
    "Logistic Regression": accuracy_score(y_test, y_pred_log),
    "KNN": accuracy_score(y_test, y_pred_knn),
    "Naïve Bayes": accuracy_score(y_test, y_pred_nb),
    "SVM": accuracy_score(y_test, y_pred_svm),
    "Decision Tree": accuracy_score(y_test, y_pred_dt),
    "Random Forest": accuracy_score(y_test, y_pred_rf),
    "Gradient Boosting": accuracy_score(y_test, y_pred_gb),
    "LightGBM": accuracy_score(y_test, y_pred_lgb),
    "AdaBoost": accuracy_score(y_test, y_pred_adaboost),
    "Voting Classifier": accuracy_score(y_test, y_pred_voting)
}

# Sort models by accuracy
sorted_models = sorted(models.items(), key=lambda x: x[1], reverse=True)

# Plot accuracy scores
plt.figure(figsize=(12, 6))
plt.barh([m[0] for m in sorted_models], [m[1] for m in sorted_models], color='skyblue')
plt.xlabel("Accuracy Score")
plt.ylabel("Machine Learning Models")
plt.title("Model Comparison: Accuracy Scores")
plt.gca().invert_yaxis()  # Highest accuracy at the top
plt.show()

# %% [markdown]
# Accuracy Comparison Graph

# %%
import matplotlib.pyplot as plt
import numpy as np

# Accuracy values from your project
models = ["Logistic Regression", "KNN", "Naïve Bayes", "SVM", "Decision Tree",
          "Random Forest", "Gradient Boosting", "LightGBM", "AdaBoost"]
accuracies = [0.850957, 0.961732, 0.801611, 0.870091, 0.956697,
              0.972810, 0.963746, 0.977845, 0.907351]

# Sort models based on accuracy in descending order
sorted_indices = np.argsort(accuracies)[::-1]  # Sort in descending order
sorted_models = [models[i] for i in sorted_indices]
sorted_accuracies = [accuracies[i] for i in sorted_indices]

# Set figure size
plt.figure(figsize=(12, 6))

# Create bar chart
plt.barh(sorted_models, sorted_accuracies, color=['brown', 'cyan', 'pink', 'green', 'blue', 'purple', 'gray', 'orange', 'red'])

# Add labels and title
plt.xlabel("Accuracy Score")
plt.ylabel("ML Models")
plt.title("Model Accuracy Comparison (Sorted)")

# Show accuracy values on bars
for index, value in enumerate(sorted_accuracies):
    plt.text(value - 0.01, index, f"{value:.3f}", va='center', ha='right', fontsize=12, color='black')

# Show the plot
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.xlim(0.75, 1.0)  # Adjust x-axis range
plt.show()

# %% [markdown]
# # Comparing accuracy and precison

# %%
from sklearn.metrics import precision_score

# Dictionary to store model performances
model_results = {}

# Define all models
models = {
    "Logistic Regression": log_model,
    "KNN": knn_model,
    "Naïve Bayes": nb_model,
    "SVM": svm_model,
    "Decision Tree": dt_model,
    "Random Forest": rf_model,
    "Gradient Boosting": gb_model,
    "LightGBM": lgb_model,
    "AdaBoost": adaboost_model,
    "Voting Classifier": voting_model
}

# Compute accuracy & precision for each model
for name, model in models.items():
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')  # Weighted for multi-class
    model_results[name] = {"Accuracy": accuracy, "Precision": precision}

# Convert results to DataFrame for better visualization
results_df = pd.DataFrame(model_results).T
print("\n Model Performance Comparison")
print(results_df)

# Plot Accuracy & Precision Comparison Graph
plt.figure(figsize=(12, 6))

# Accuracy Bar Chart
plt.subplot(1, 2, 1)
plt.barh(results_df.index, results_df["Accuracy"], color='lightblue')
plt.xlabel("Accuracy Score")
plt.title("Model Comparison: Accuracy")
plt.xlim(0, 1)

# Precision Bar Chart
plt.subplot(1, 2, 2)
plt.barh(results_df.index, results_df["Precision"], color='lightcoral')
plt.xlabel("Precision Score")
plt.title("Model Comparison: Precision")
plt.xlim(0, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# # ROC Comparison

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Binarize the labels for multi-class classification (One-vs-Rest strategy)
y_test_bin = label_binarize(y_test, classes=[1, 2, 3])
n_classes = y_test_bin.shape[1]

# Get predicted probabilities
y_score_lgb = lgb_model.predict_proba(X_test)
y_score_nb = nb_model.predict_proba(X_test)

# Define colors for different classes
colors = cycle(["blue", "green", "red"])

plt.figure(figsize=(12, 5))

# =======  LightGBM ROC Curve =======
plt.subplot(1, 2, 1)
for i, color in zip(range(n_classes), colors):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_score_lgb[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, label=f'Class {i+1} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], "k--")  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - LightGBM")
plt.legend(loc="lower right")

# =======  Naïve Bayes ROC Curve =======
plt.subplot(1, 2, 2)
colors = cycle(["blue", "green", "red"])  # Reset colors
for i, color in zip(range(n_classes), colors):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_score_nb[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, label=f'Class {i+1} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], "k--")  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Naïve Bayes")
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()

# %% [markdown]
# #Stacking Classifier - Strong & Weak Models

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier

# Define base models
base_models = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
    ('gb', GradientBoostingClassifier(n_estimators=100, random_state=42)),
    ('lgbm', LGBMClassifier(n_estimators=100, random_state=42))
]

# Meta-model (final decision maker)
meta_model = LogisticRegression()

# Create stacking classifier
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5)

# Train the stacking classifier
stacking_clf.fit(X_train, y_train)

# Evaluate model
y_pred_stack = stacking_clf.predict(X_test)

# Print accuracy and precision
from sklearn.metrics import accuracy_score, precision_score

print("Stacking Classifier Accuracy:", accuracy_score(y_test, y_pred_stack))
print("Stacking Classifier Precision:", precision_score(y_test, y_pred_stack, average='weighted'))

# %% [markdown]
# Analysis

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Define base models
base_models = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('gb', GradientBoostingClassifier(n_estimators=100, random_state=42)),
    ('nb', GaussianNB()),
    ('svm', SVC(probability=True, random_state=42))
]

# Define meta-model
meta_model = LGBMClassifier(n_estimators=100, random_state=42)

# Create Stacking Classifier
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5)

# Train the Stacking Classifier
stacking_clf.fit(X_train, y_train)

# Make predictions
y_pred = stacking_clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
print("Stacking Classifier Accuracy:", accuracy)
print("Stacking Classifier Precision:", precision)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
plt.figure(figsize=(6, 5))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[1, 2, 3], yticklabels=[1, 2, 3])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Stacking Classifier")
plt.show()

# %% [markdown]
# #Stacking Classifier with RF, GB, SVM & LR.

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, classification_report

# Define Base Models (Stronger Models)
base_models = [
    ('rf', RandomForestClassifier(n_estimators=200, random_state=42)),
    ('gb', GradientBoostingClassifier(n_estimators=200, learning_rate=0.1, random_state=42)),
    ('svm', SVC(probability=True, kernel='rbf', C=1.0, random_state=42))
]

# Meta-Model (Simple but Effective)
meta_model = LogisticRegression()

# Define Stacking Classifier
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5, n_jobs=-1)

# Train Stacking Model
stacking_clf.fit(X_train, y_train)

# Predictions
y_pred = stacking_clf.predict(X_test)

# Model Evaluation
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

print(f"Stacking Classifier Accuracy: {accuracy:.4f}")
print(f"Stacking Classifier Precision: {precision:.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# %% [markdown]
# # Stacking Classifier with Low-Accuracy Models(LR, NB, KNN, DT)

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Define base models (low accuracy models)
base_models = [
    ('lr', LogisticRegression(max_iter=1000, random_state=42)),
    ('nb', GaussianNB()),
    ('knn', KNeighborsClassifier(n_neighbors=5)),
    ('dt', DecisionTreeClassifier(random_state=42))
]

# Define meta-model (final model)
meta_model = SVC(probability=True, random_state=42)

# Create Stacking Classifier
stacking_clf_low = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5)

# Train the model
stacking_clf_low.fit(X_train, y_train)

# Predictions
y_pred = stacking_clf_low.predict(X_test)

# Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

print("Stacking Classifier (Low Accuracy Models) Accuracy:", accuracy)
print("Stacking Classifier (Low Accuracy Models) Precision:", precision)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=[1, 2, 3], yticklabels=[1, 2, 3])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Stacking (Low Accuracy Models)")
plt.show()

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# %% [markdown]
# # Stacking Classifier with High-Performance Models (RF, Gradient Boosting, LightGBM)

# %%
import warnings
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import StackingClassifier, RandomForestClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# 🔹 Suppress Warnings (LightGBM & Deprecation Warnings)
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler

# Apply Standard Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 🔹 Step 1: Define High-Performance Base Models
base_models = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
    ('gb', GradientBoostingClassifier(n_estimators=100, random_state=42)),
    ('lgbm', LGBMClassifier(n_estimators=100, random_state=42, verbose=-1))  # Suppress LGBM warnings
]

# 🔹 Step 2: Define Meta-Model
meta_model = LogisticRegression(max_iter=1000, random_state=42, class_weight='balanced')

# 🔹 Step 3: Create & Train Stacking Classifier
stacking_clf_high = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5)
stacking_clf_high.fit(X_train, y_train)

# 🔹 Step 4: Make Predictions
y_pred_high = stacking_clf_high.predict(X_test)

# 🔹 Step 5: Evaluate Performance
accuracy_high = accuracy_score(y_test, y_pred_high)
precision_high = precision_score(y_test, y_pred_high, average='weighted')

print(" Stacking Classifier (High-Performance Models) Accuracy:", accuracy_high)
print(" Stacking Classifier (High-Performance Models) Precision:", precision_high)

# 🔹 Step 6: Confusion Matrix
conf_matrix_high = confusion_matrix(y_test, y_pred_high)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_high, annot=True, fmt='d', cmap='Blues', xticklabels=[1, 2, 3], yticklabels=[1, 2, 3])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Stacking (High-Performance Models)")
plt.show()

# 🔹 Step 7: Classification Report
print("\n🔹 Classification Report:\n", classification_report(y_test, y_pred_high))

# 🔹 Step 8: Generate ROC Curve for Multi-Class Classification
y_test_bin = label_binarize(y_test, classes=[1, 2, 3])  # Convert labels into binary format
n_classes = y_test_bin.shape[1]

# Get predicted probabilities
y_score_stacking = stacking_clf_high.predict_proba(X_test)

# Define colors for classes
colors = cycle(["blue", "green", "red"])

plt.figure(figsize=(10, 5))

for i, color in zip(range(n_classes), colors):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_score_stacking[:, i])
    plt.plot(fpr, tpr, color=color, label=f'Class {i+1} (AUC = {auc(fpr, tpr):.2f})')

plt.title("ROC Curve - Stacking Classifier (High-Performance Models)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %% [markdown]
# # Comparison graph

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define model names and their corresponding performance
models = ['Weak Stacking', 'Strong Stacking']
accuracy_scores = [accuracy, accuracy_high]  # Replace with actual values
precision_scores = [precision, precision_high]  # Replace with actual values

# Set bar width
bar_width = 0.3

# X locations for bars
x = np.arange(len(models))

# Create bar chart
fig, ax = plt.subplots(figsize=(8, 6))

bars1 = ax.bar(x - bar_width/2, accuracy_scores, bar_width, label='Accuracy', color='blue')
bars2 = ax.bar(x + bar_width/2, precision_scores, bar_width, label='Precision', color='green')

# Add labels and title
ax.set_xlabel('Stacking Classifier Models')
ax.set_ylabel('Performance Score')
ax.set_title('Comparison: Weak vs. Strong Stacking Classifier')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()

# Display values on top of bars
for bars in [bars1, bars2]:
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 3), ha='center', va='bottom')

# Show plot
plt.show()

# %% [markdown]
# # Hyperparameter Tuning for Stacking Classifier

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import StackingClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report

# 🟢 Step 1: Optimize LightGBM
best_lgbm = LGBMClassifier(
    n_estimators=200,  #  Reduced from 500 to 200
    learning_rate=0.05,
    max_depth=6,
    num_leaves=25,
    min_data_in_leaf=15,  #  Allows better splits
    boosting_type='gbdt',
    random_state=42,
    verbose=-1
)

# 🟢 Step 2: Define Base Model (Simplified)
base_models = [('lgbm', best_lgbm)]  #  Only LightGBM

# Define Meta Model
meta_model = LogisticRegression(max_iter=1000, random_state=42)

# 🟢 Step 3: Create & Train Stacking Classifier
stacking_clf_optimized = StackingClassifier(
    estimators=base_models,
    final_estimator=meta_model,
    cv=3  #  Reduced cross-validation folds
)

stacking_clf_optimized.fit(X_train, y_train)

# 🟢 Step 4: Make Predictions
y_pred_optimized = stacking_clf_optimized.predict(X_test)

# 🟢 Step 5: Evaluate Performance
accuracy_optimized = accuracy_score(y_test, y_pred_optimized)
precision_optimized = precision_score(y_test, y_pred_optimized, average='weighted')

print(" Optimized Stacking Classifier Accuracy:", accuracy_optimized)
print(" Optimized Stacking Classifier Precision:", precision_optimized)

# 🟢 Step 6: Confusion Matrix
conf_matrix_optimized = confusion_matrix(y_test, y_pred_optimized)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_optimized, annot=True, fmt='d', cmap='Blues', xticklabels=[1, 2, 3], yticklabels=[1, 2, 3])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Optimized Stacking")
plt.show()

# 🟢 Step 7: Classification Report
print("\n Classification Report:\n", classification_report(y_test, y_pred_optimized))

# %% [markdown]
# # ROC Curve for Stacking Classifier(optimized)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Binarize labels for multi-class classification
y_test_bin = label_binarize(y_test, classes=[1, 2, 3])
n_classes = y_test_bin.shape[1]

# Get predicted probabilities
y_score_stacking = stacking_clf_optimized.predict_proba(X_test)

# Define colors
colors = cycle(["blue", "green", "red"])

plt.figure(figsize=(10, 5))

for i, color in zip(range(n_classes), colors):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_score_stacking[:, i])
    plt.plot(fpr, tpr, color=color, label=f'Class {i+1} (AUC = {auc(fpr, tpr):.2f})')

plt.title("ROC Curve - Optimized Stacking Classifier")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %% [markdown]
# # Compare Performance with Other Models

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score
# Dictionary to store model performances
model_results = {}

# Define all models (excluding Voting Classifier, adding Stacking & Optimized Stacking)
models = {
    "Logistic Regression": log_model,
    "KNN": knn_model,
    "Naïve Bayes": nb_model,
    "SVM": svm_model,
    "Decision Tree": dt_model,
    "Random Forest": rf_model,
    "Gradient Boosting": gb_model,
    "LightGBM": lgb_model,
    "AdaBoost": adaboost_model,
    "Stacking Classifier (High-Performance)": stacking_clf_high,  #  High-Performance Stacking
    "Stacking Classifier (Optimized)": stacking_clf_optimized     #  Optimized Stacking
}

# Compute accuracy & precision for each model
for name, model in models.items():
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')  # Weighted for multi-class
    model_results[name] = {"Accuracy": accuracy, "Precision": precision}

# Convert results to DataFrame and sort by Accuracy
results_df = pd.DataFrame(model_results).T
results_df = results_df.sort_values(by="Accuracy", ascending=False)  #  Sort by Accuracy

print("\n Model Performance Comparison (Sorted by Accuracy)")
print(results_df)

# 🔹 Plot Accuracy & Precision Comparison Graph (Sorted Order)
plt.figure(figsize=(12, 6))

# Accuracy Bar Chart
plt.subplot(1, 2, 1)
plt.barh(results_df.index, results_df["Accuracy"], color='lightblue', edgecolor='black')
plt.xlabel("Accuracy Score")
plt.title("🔹 Model Comparison: Accuracy")
plt.xlim(0, 1)
plt.gca().invert_yaxis()  #  Keeps highest accuracy at the top

# Precision Bar Chart
plt.subplot(1, 2, 2)
plt.barh(results_df.index, results_df["Precision"], color='lightcoral', edgecolor='black')
plt.xlabel("Precision Score")
plt.title("🔹 Model Comparison: Precision")
plt.xlim(0, 1)
plt.gca().invert_yaxis()  #  Keeps highest precision at the top

plt.tight_layout()
plt.show()

# %% [markdown]
# # Finalize the Best Model

# %%
#Compare Training Time

import time

# Measure High-Performance Stacking Training Time
start_time = time.time()
stacking_clf_high.fit(X_train, y_train)
high_perf_time = time.time() - start_time

# Measure Optimized Stacking Training Time
start_time = time.time()
stacking_clf_optimized.fit(X_train, y_train)
optimized_time = time.time() - start_time

# Measure LightGBM Training Time
start_time = time.time()
lgb_model.fit(X_train, y_train)
lgb_time = time.time() - start_time

# Print Training Times
print(f" High-Performance Stacking Training Time: {high_perf_time:.2f} sec")
print(f" Optimized Stacking Training Time: {optimized_time:.2f} sec")
print(f" LightGBM Training Time: {lgb_time:.2f} sec")

# %%
from sklearn.model_selection import cross_val_score

# Perform Cross-Validation
cv_scores_high = cross_val_score(stacking_clf_high, X, y, cv=5, scoring='accuracy')
cv_scores_optimized = cross_val_score(stacking_clf_optimized, X, y, cv=5, scoring='accuracy')
cv_scores_lgb = cross_val_score(lgb_model, X, y, cv=5, scoring='accuracy')

# Print Mean & Std Deviation
print(f" High-Performance Stacking - Mean Accuracy: {cv_scores_high.mean():.4f}, Std: {cv_scores_high.std():.4f}")
print(f" Optimized Stacking - Mean Accuracy: {cv_scores_optimized.mean():.4f}, Std: {cv_scores_optimized.std():.4f}")
print(f" LightGBM - Mean Accuracy: {cv_scores_lgb.mean():.4f}, Std: {cv_scores_lgb.std():.4f}")

# %%
import numpy as np

# Example Test Case
new_sample = np.array([[120, 10, 0.5, 2.3, 180, 10, 0.01, 0.03, 0.02, 0.04]])
new_sample_scaled = scaler.transform(new_sample)

# Predictions
pred_high = stacking_clf_high.predict(new_sample_scaled)
pred_optimized = stacking_clf_optimized.predict(new_sample_scaled)
pred_lgb = lgb_model.predict(new_sample_scaled)

# Convert to Labels
health_conditions = {1: "Normal", 2: "Suspect", 3: "Pathological"}
print(f" High-Performance Stacking Prediction: {health_conditions[pred_high[0]]}")
print(f" Optimized Stacking Prediction: {health_conditions[pred_optimized[0]]}")
print(f" LightGBM Prediction: {health_conditions[pred_lgb[0]]}")

# %% [markdown]
# # Save & Load the Final Model( High-Performance Stacking)
#
# ---

# %%
import joblib

# Save the trained stacking model
joblib.dump(stacking_clf_high, "high_performance_stacking.pkl")
print(" Model Saved Successfully!")

# %%
# Load the model without retraining
stacking_clf_high = joblib.load("high_performance_stacking.pkl")
print(" Model Loaded Successfully!")

# Now, use it for predictions without retraining

# %%
import numpy as np

# Example test cases
new_samples = np.array([
    [120, 10, 0.5, 2.3, 180, 10, 0.01, 0.03, 0.02, 0.04],  # Expected: Normal
    [160, 20, 1.0, 3.5, 190, 15, 0.03, 0.05, 0.06, 0.07],  # Expected: Suspect
    [200, 40, 1.8, 4.2, 200, 30, 0.05, 0.07, 0.08, 0.09]   # Expected: Pathological
])

# Apply correct feature scaling
new_samples_scaled = scaler.transform(new_samples)

# Get Prediction Probabilities
y_probs = stacking_clf_high.predict_proba(new_samples_scaled)

# Print class probabilities
for i, probs in enumerate(y_probs):
    print(f"🩺 Sample {i+1} → Class Probabilities: {probs}")

# Adjust probability thresholds
threshold_suspect = 0.18  # Detect Suspect cases better
threshold_pathological = 0.10  # Prevent false Pathological classifications

adjusted_preds = []
for prob in y_probs:
    if prob[2] >= threshold_pathological:  # If "Pathological" probability is high enough
        adjusted_preds.append(3)  # Pathological
    elif prob[1] >= threshold_suspect:  # If "Suspect" probability is high enough
        adjusted_preds.append(2)  # Suspect
    else:
        adjusted_preds.append(1)  # Normal

# Define label mapping
health_conditions = {1: "Normal", 2: "Suspect", 3: "Pathological"}

# Print Adjusted Predictions
for i, pred in enumerate(adjusted_preds):
    print(f"🩺 Sample {i+1} → Adjusted Prediction: {health_conditions[pred]}")

# %%
# Print class probabilities
for i, probs in enumerate(y_probs):
    print(f"🩺 Sample {i+1} → Class Probabilities: {probs}")

# %% [markdown]
# # Test Real Data

# %%
import numpy as np

# 🔹 Select 10 random test samples
num_samples = 10
random_indices = np.random.choice(len(X_test), num_samples, replace=False)
test_samples = X_test[random_indices]

# 🔹 Get Prediction Probabilities for Real Test Data
y_probs_test = stacking_clf_high.predict_proba(test_samples)

# 🔹 Print Class Probabilities for Each Sample
print("\n🔹 Class Probabilities for Real Test Data:")
for i, probs in enumerate(y_probs_test):
    print(f" Test Sample {i+1} → Probabilities: {probs}")

# 🔹 Adjust Probability Thresholds for Classification
threshold_suspect = 0.18  # Adjusted for better suspect detection
threshold_pathological = 0.10  # Lowered to better classify pathological cases

adjusted_preds_test = []
for prob in y_probs_test:
    if prob[2] >= threshold_pathological:  # If "Pathological" probability is high enough
        adjusted_preds_test.append(3)  # Pathological
    elif prob[1] >= threshold_suspect:  # If "Suspect" probability is high enough
        adjusted_preds_test.append(2)  # Suspect
    else:
        adjusted_preds_test.append(1)  # Normal

# 🔹 Print Adjusted Predictions for Real Test Data
health_conditions = {1: "Normal", 2: "Suspect", 3: "Pathological"}
print("\n Adjusted Predictions for Real Test Data:")
for i, pred in enumerate(adjusted_preds_test):
    print(f" Test Sample {i+1} → Adjusted Prediction: {health_conditions[pred]}")
# Out:
# 🔹 Class Probabilities for Real Test Data:
#  Test Sample 1 → Probabilities: [0.75704634 0.23456063 0.00839303]
#  Test Sample 2 → Probabilities: [0.01296492 0.98347195 0.00356313]
#  Test Sample 3 → Probabilities: [0.93541131 0.06195632 0.00263237]
#  Test Sample 4 → Probabilities: [0.00365095 0.00278316 0.99356589]
#  Test Sample 5 → Probabilities: [9.94828637e-01 4.71872760e-03 4.52635100e-04]
#  Test Sample 6 → Probabilities: [0.00349266 0.00259478 0.99391255]
#  Test Sample 7 → Probabilities: [0.01656161 0.97998811 0.00345028]
#  Test Sample 8 → Probabilities: [9.94828383e-01 4.71984955e-03 4.51767351e-04]
#  Test Sample 9 → Probabilities: [9.94265882e-01 5.17552617e-03 5.58591709e-04]
#  Test Sample 10 → Probabilities: [0.01538974 0.97967677 0.0049335 ]
#
#  Adjusted Predictions for Real Test Data:
#  Test Sample 1 → Adjusted Prediction: Suspect
#  Test Sample 2 → Adjusted Prediction: Suspect
#  Test Sample 3 → Adjusted Prediction: Normal
#  Test Sample 4 → Adjusted Prediction: Pathological
#  Test Sample 5 → Adjusted Prediction: Normal
#  Test Sample 6 → Adjusted Prediction: Pathological
#  Test Sample 7 → Adjusted Prediction: Suspect
#  Test Sample 8 → Adjusted Prediction: Normal
#  Test Sample 9 → Adjusted Prediction: Normal
#  Test Sample 10 → Adjusted Prediction: Suspect

# %% [markdown]
# # Debugg

# %%
# Get prediction probabilities for test set
y_probs = stacking_clf_high.predict_proba(X_test)

# Print probabilities for first few samples
for i, probs in enumerate(y_probs[:5]):  # Print only first 5 for readability
    print(f" Sample {i+1} → Class Probabilities: {probs}")
# Out:
#  Sample 1 → Class Probabilities: [9.94810347e-01 4.73045582e-03 4.59197321e-04]
#  Sample 2 → Class Probabilities: [0.01179611 0.98514017 0.00306371]
#  Sample 3 → Class Probabilities: [0.01159206 0.98535891 0.00304903]
#  Sample 4 → Class Probabilities: [0.00350575 0.00259639 0.99389786]
#  Sample 5 → Class Probabilities: [9.92936623e-01 6.50407520e-03 5.59301912e-04]

# %%
threshold_suspect = 0.50  # Adjust based on actual probabilities
threshold_pathological = 0.50

adjusted_preds = []
for prob in y_probs:
    if prob[2] >= threshold_pathological:  # If "Pathological" has high confidence, predict it
        adjusted_preds.append(3)
    elif prob[1] >= threshold_suspect:  # If "Suspect" has high confidence, predict it
        adjusted_preds.append(2)
    else:
        adjusted_preds.append(1)  # Default to "Normal"

# Define label mapping
health_conditions = {1: "Normal", 2: "Suspect", 3: "Pathological"}

# Print Adjusted Predictions
for i, pred in enumerate(adjusted_preds):
    print(f"🩺 Sample {i+1} → Adjusted Prediction: {health_conditions[pred]}")
# Out:
# 🩺 Sample 1 → Adjusted Prediction: Normal
# 🩺 Sample 2 → Adjusted Prediction: Suspect
# 🩺 Sample 3 → Adjusted Prediction: Suspect
# 🩺 Sample 4 → Adjusted Prediction: Pathological
# 🩺 Sample 5 → Adjusted Prediction: Normal
# 🩺 Sample 6 → Adjusted Prediction: Pathological
# 🩺 Sample 7 → Adjusted Prediction: Pathological
# 🩺 Sample 8 → Adjusted Prediction: Suspect
# 🩺 Sample 9 → Adjusted Prediction: Suspect
# 🩺 Sample 10 → Adjusted Prediction: Suspect
# 🩺 Sample 11 → Adjusted Prediction: Suspect
# 🩺 Sample 12 → Adjusted Prediction: Pathological
# 🩺 Sample 13 → Adjusted Prediction: Normal
# 🩺 Sample 14 → Adjusted Prediction: Normal
# 🩺 Sample 15 → Adjusted Prediction: Pathological
# 🩺 Sample 16 → Adjusted Prediction: Pathological
# 🩺 Sample 17 → Adjusted Prediction: Suspect
# 🩺 Sample 18 → Adjusted Prediction: Suspect
# 🩺 Sample 19 → Adjusted Prediction: Suspect
# 🩺 Sample 20 → Adjusted Prediction: Pathological
# 🩺 Sample 21 → Adjusted Prediction: Suspect
# 🩺 Sample 22 → Adjusted Prediction: Normal
# 🩺 Sample 23 → Adjusted Prediction: Pathological
# 🩺 Sample 24 → Adjusted Prediction: Pathological
# 🩺 Sample 25 → Adjusted Prediction: Suspect
# 🩺 Sample 26 → Adjusted Prediction: Suspect
# 🩺 Sample 27 → Adjusted Prediction: Pathological
# 🩺 Sample 28 → Adjusted Prediction: Pathological
# 🩺 Sample 29 → Adjusted Prediction: Normal
# 🩺 Sample 30 → Adjusted Prediction: Pathological
# 🩺 Sample 31 → Adjusted Prediction: Pathological
# 🩺 Sample 32 → Adjusted Prediction: Pathological
# 🩺 Sample 33 → Adjusted Prediction: Suspect
# 🩺 Sample 34 → Adjusted Prediction: Pathological
# 🩺 Sample 35 → Adjusted Prediction: Suspect
# 🩺 Sample 36 → Adjusted Prediction: Pathological
# 🩺 Sample 37 → Adjusted Prediction: Pathological
# 🩺 Sample 38 → Adjusted Prediction: Normal
# 🩺 Sample 39 → Adjusted Prediction: Pathological
# 🩺 Sample 40 → Adjusted Prediction: Pathological
# 🩺 Sample 41 → Adjusted Prediction: Pathological
# 🩺 Sample 42 → Adjusted Prediction: Pathological
# 🩺 Sample 43 → Adjusted Prediction: Pathological
# 🩺 Sample 44 → Adjusted Prediction: Suspect
# 🩺 Sample 45 → Adjusted Prediction: Suspect
# 🩺 Sample 46 → Adjusted Prediction: Pathological
# 🩺 Sample 47 → Adjusted Prediction: Suspect
# 🩺 Sample 48 → Adjusted Prediction: Suspect
# 🩺 Sample 49 → Adjusted Prediction: Suspect
# 🩺 Sample 50 → Adjusted Prediction: Normal
# 🩺 Sample 51 → Adjusted Prediction: Pathological
# 🩺 Sample 52 → Adjusted Prediction: Pathological
# 🩺 Sample 53 → Adjusted Prediction: Suspect
# 🩺 Sample 54 → Adjusted Prediction: Pathological
# 🩺 Sample 55 → Adjusted Prediction: Normal
# 🩺 Sample 56 → Adjusted Prediction: Suspect
# 🩺 Sample 57 → Adjusted Prediction: Normal
# 🩺 Sample 58 → Adjusted Prediction: Normal
# 🩺 Sample 59 → Adjusted Prediction: Suspect
# 🩺 Sample 60 → Adjusted Prediction: Pathological
# 🩺 Sample 61 → Adjusted Prediction: Normal
# 🩺 Sample 62 → Adjusted Prediction: Suspect
# 🩺 Sample 63 → Adjusted Prediction: Normal
# 🩺 Sample 64 → Adjusted Prediction: Suspect
# 🩺 Sample 65 → Adjusted Prediction: Suspect
# 🩺 Sample 66 → Adjusted Prediction: Suspect
# 🩺 Sample 67 → Adjusted Prediction: Pathological
# 🩺 Sample 68 → Adjusted Prediction: Pathological
# 🩺 Sample 69 → Adjusted Prediction: Normal
# 🩺 Sample 70 → Adjusted Prediction: Suspect
# 🩺 Sample 71 → Adjusted Prediction: Normal
# 🩺 Sample 72 → Adjusted Prediction: Pathological
# 🩺 Sample 73 → Adjusted Prediction: Pathological
# 🩺 Sample 74 → Adjusted Prediction: Pathological
# 🩺 Sample 75 → Adjusted Prediction: Normal
# 🩺 Sample 76 → Adjusted Prediction: Normal
# 🩺 Sample 77 → Adjusted Prediction: Suspect
# 🩺 Sample 78 → Adjusted Prediction: Normal
# 🩺 Sample 79 → Adjusted Prediction: Normal
# 🩺 Sample 80 → Adjusted Prediction: Normal
# 🩺 Sample 81 → Adjusted Prediction: Suspect
# 🩺 Sample 82 → Adjusted Prediction: Suspect
# 🩺 Sample 83 → Adjusted Prediction: Pathological
# 🩺 Sample 84 → Adjusted Prediction: Normal
# 🩺 Sample 85 → Adjusted Prediction: Normal
# 🩺 Sample 86 → Adjusted Prediction: Suspect
# 🩺 Sample 87 → Adjusted Prediction: Pathological
# 🩺 Sample 88 → Adjusted Prediction: Normal
# 🩺 Sample 89 → Adjusted Prediction: Pathological
# 🩺 Sample 90 → Adjusted Prediction: Pathological
# 🩺 Sample 91 → Adjusted Prediction: Pathological
# 🩺 Sample 92 → Adjusted Prediction: Suspect
# 🩺 Sample 93 → Adjusted Prediction: Normal
# 🩺 Sample 94 → Adjusted Prediction: Suspect
# 🩺 Sample 95 → Adjusted Prediction: Pathological
# 🩺 Sample 96 → Adjusted Prediction: Pathological
# 🩺 Sample 97 → Adjusted Prediction: Pathological
# 🩺 Sample 98 → Adjusted Prediction: Normal
# 🩺 Sample 99 → Adjusted Prediction: Normal
# 🩺 Sample 100 → Adjusted Prediction: Normal
# 🩺 Sample 101 → Adjusted Prediction: Suspect
# 🩺 Sample 102 → Adjusted Prediction: Pathological
# 🩺 Sample 103 → Adjusted Prediction: Normal
# 🩺 Sample 104 → Adjusted Prediction: Suspect
# 🩺 Sample 105 → Adjusted Prediction: Normal
# 🩺 Sample 106 → Adjusted Prediction: Pathological
# 🩺 Sample 107 → Adjusted Prediction: Normal
# 🩺 Sample 108 → Adjusted Prediction: Normal
# 🩺 Sample 109 → Adjusted Prediction: Pathological
# 🩺 Sample 110 → Adjusted Prediction: Pathological
# 🩺 Sample 111 → Adjusted Prediction: Normal
# 🩺 Sample 112 → Adjusted Prediction: Normal
# 🩺 Sample 113 → Adjusted Prediction: Normal
# 🩺 Sample 114 → Adjusted Prediction: Suspect
# 🩺 Sample 115 → Adjusted Prediction: Suspect
# 🩺 Sample 116 → Adjusted Prediction: Normal
# 🩺 Sample 117 → Adjusted Prediction: Pathological
# 🩺 Sample 118 → Adjusted Prediction: Suspect
# 🩺 Sample 119 → Adjusted Prediction: Suspect
# 🩺 Sample 120 → Adjusted Prediction: Suspect
# 🩺 Sample 121 → Adjusted Prediction: Normal
# 🩺 Sample 122 → Adjusted Prediction: Suspect
# 🩺 Sample 123 → Adjusted Prediction: Normal
# 🩺 Sample 124 → Adjusted Prediction: Suspect
# 🩺 Sample 125 → Adjusted Prediction: Suspect
# 🩺 Sample 126 → Adjusted Prediction: Suspect
# 🩺 Sample 127 → Adjusted Prediction: Pathological
# 🩺 Sample 128 → Adjusted Prediction: Normal
# 🩺 Sample 129 → Adjusted Prediction: Normal
# 🩺 Sample 130 → Adjusted Prediction: Suspect
# 🩺 Sample 131 → Adjusted Prediction: Normal
# 🩺 Sample 132 → Adjusted Prediction: Suspect
# 🩺 Sample 133 → Adjusted Prediction: Normal
# 🩺 Sample 134 → Adjusted Prediction: Normal
# 🩺 Sample 135 → Adjusted Prediction: Normal
# 🩺 Sample 136 → Adjusted Prediction: Pathological
# 🩺 Sample 137 → Adjusted Prediction: Pathological
# 🩺 Sample 138 → Adjusted Prediction: Pathological
# 🩺 Sample 139 → Adjusted Prediction: Pathological
# 🩺 Sample 140 → Adjusted Prediction: Normal
# 🩺 Sample 141 → Adjusted Prediction: Normal
# 🩺 Sample 142 → Adjusted Prediction: Normal
# 🩺 Sample 143 → Adjusted Prediction: Suspect
# 🩺 Sample 144 → Adjusted Prediction: Suspect
# 🩺 Sample 145 → Adjusted Prediction: Suspect
# 🩺 Sample 146 → Adjusted Prediction: Suspect
# 🩺 Sample 147 → Adjusted Prediction: Suspect
# 🩺 Sample 148 → Adjusted Prediction: Normal
# 🩺 Sample 149 → Adjusted Prediction: Pathological
# 🩺 Sample 150 → Adjusted Prediction: Normal
# 🩺 Sample 151 → Adjusted Prediction: Pathological
# 🩺 Sample 152 → Adjusted Prediction: Suspect
# 🩺 Sample 153 → Adjusted Prediction: Suspect
# 🩺 Sample 154 → Adjusted Prediction: Normal
# 🩺 Sample 155 → Adjusted Prediction: Normal
# 🩺 Sample 156 → Adjusted Prediction: Normal
# 🩺 Sample 157 → Adjusted Prediction: Normal
# 🩺 Sample 158 → Adjusted Prediction: Normal
# 🩺 Sample 159 → Adjusted Prediction: Normal
# 🩺 Sample 160 → Adjusted Prediction: Suspect
# 🩺 Sample 161 → Adjusted Prediction: Suspect
# 🩺 Sample 162 → Adjusted Prediction: Suspect
# 🩺 Sample 163 → Adjusted Prediction: Normal
# 🩺 Sample 164 → Adjusted Prediction: Pathological
# 🩺 Sample 165 → Adjusted Prediction: Normal
# 🩺 Sample 166 → Adjusted Prediction: Pathological
# 🩺 Sample 167 → Adjusted Prediction: Suspect
# 🩺 Sample 168 → Adjusted Prediction: Suspect
# 🩺 Sample 169 → Adjusted Prediction: Pathological
# 🩺 Sample 170 → Adjusted Prediction: Suspect
# 🩺 Sample 171 → Adjusted Prediction: Normal
# 🩺 Sample 172 → Adjusted Prediction: Pathological
# 🩺 Sample 173 → Adjusted Prediction: Normal
# 🩺 Sample 174 → Adjusted Prediction: Suspect
# 🩺 Sample 175 → Adjusted Prediction: Pathological
# 🩺 Sample 176 → Adjusted Prediction: Normal
# 🩺 Sample 177 → Adjusted Prediction: Normal
# 🩺 Sample 178 → Adjusted Prediction: Suspect
# 🩺 Sample 179 → Adjusted Prediction: Normal
# 🩺 Sample 180 → Adjusted Prediction: Suspect
# 🩺 Sample 181 → Adjusted Prediction: Pathological
# 🩺 Sample 182 → Adjusted Prediction: Normal
# 🩺 Sample 183 → Adjusted Prediction: Suspect
# 🩺 Sample 184 → Adjusted Prediction: Pathological
# 🩺 Sample 185 → Adjusted Prediction: Pathological
# 🩺 Sample 186 → Adjusted Prediction: Suspect
# 🩺 Sample 187 → Adjusted Prediction: Suspect
# 🩺 Sample 188 → Adjusted Prediction: Suspect
# 🩺 Sample 189 → Adjusted Prediction: Suspect
# 🩺 Sample 190 → Adjusted Prediction: Pathological
# 🩺 Sample 191 → Adjusted Prediction: Pathological
# 🩺 Sample 192 → Adjusted Prediction: Pathological
# 🩺 Sample 193 → Adjusted Prediction: Pathological
# 🩺 Sample 194 → Adjusted Prediction: Normal
# 🩺 Sample 195 → Adjusted Prediction: Pathological
# 🩺 Sample 196 → Adjusted Prediction: Normal
# 🩺 Sample 197 → Adjusted Prediction: Normal
# 🩺 Sample 198 → Adjusted Prediction: Pathological
# 🩺 Sample 199 → Adjusted Prediction: Normal
# 🩺 Sample 200 → Adjusted Prediction: Pathological
# 🩺 Sample 201 → Adjusted Prediction: Normal
# 🩺 Sample 202 → Adjusted Prediction: Suspect
# 🩺 Sample 203 → Adjusted Prediction: Suspect
# 🩺 Sample 204 → Adjusted Prediction: Pathological
# 🩺 Sample 205 → Adjusted Prediction: Suspect
# 🩺 Sample 206 → Adjusted Prediction: Suspect
# 🩺 Sample 207 → Adjusted Prediction: Pathological
# 🩺 Sample 208 → Adjusted Prediction: Normal
# 🩺 Sample 209 → Adjusted Prediction: Pathological
# 🩺 Sample 210 → Adjusted Prediction: Pathological
# 🩺 Sample 211 → Adjusted Prediction: Normal
# 🩺 Sample 212 → Adjusted Prediction: Pathological
# 🩺 Sample 213 → Adjusted Prediction: Pathological
# 🩺 Sample 214 → Adjusted Prediction: Suspect
# 🩺 Sample 215 → Adjusted Prediction: Suspect
# 🩺 Sample 216 → Adjusted Prediction: Suspect
# 🩺 Sample 217 → Adjusted Prediction: Normal
# 🩺 Sample 218 → Adjusted Prediction: Normal
# 🩺 Sample 219 → Adjusted Prediction: Normal
# 🩺 Sample 220 → Adjusted Prediction: Normal
# 🩺 Sample 221 → Adjusted Prediction: Normal
# 🩺 Sample 222 → Adjusted Prediction: Pathological
# 🩺 Sample 223 → Adjusted Prediction: Normal
# 🩺 Sample 224 → Adjusted Prediction: Normal
# 🩺 Sample 225 → Adjusted Prediction: Pathological
# 🩺 Sample 226 → Adjusted Prediction: Normal
# 🩺 Sample 227 → Adjusted Prediction: Pathological
# 🩺 Sample 228 → Adjusted Prediction: Pathological
# 🩺 Sample 229 → Adjusted Prediction: Pathological
# 🩺 Sample 230 → Adjusted Prediction: Suspect
# 🩺 Sample 231 → Adjusted Prediction: Normal
# 🩺 Sample 232 → Adjusted Prediction: Normal
# 🩺 Sample 233 → Adjusted Prediction: Pathological
# 🩺 Sample 234 → Adjusted Prediction: Suspect
# 🩺 Sample 235 → Adjusted Prediction: Suspect
# 🩺 Sample 236 → Adjusted Prediction: Normal
# 🩺 Sample 237 → Adjusted Prediction: Normal
# 🩺 Sample 238 → Adjusted Prediction: Normal
# 🩺 Sample 239 → Adjusted Prediction: Pathological
# 🩺 Sample 240 → Adjusted Prediction: Pathological
# 🩺 Sample 241 → Adjusted Prediction: Pathological
# 🩺 Sample 242 → Adjusted Prediction: Normal
# 🩺 Sample 243 → Adjusted Prediction: Pathological
# 🩺 Sample 244 → Adjusted Prediction: Normal
# 🩺 Sample 245 → Adjusted Prediction: Pathological
# 🩺 Sample 246 → Adjusted Prediction: Pathological
# 🩺 Sample 247 → Adjusted Prediction: Normal
# 🩺 Sample 248 → Adjusted Prediction: Normal
# 🩺 Sample 249 → Adjusted Prediction: Pathological
# 🩺 Sample 250 → Adjusted Prediction: Pathological
# 🩺 Sample 251 → Adjusted Prediction: Suspect
# 🩺 Sample 252 → Adjusted Prediction: Normal
# 🩺 Sample 253 → Adjusted Prediction: Suspect
# 🩺 Sample 254 → Adjusted Prediction: Normal
# 🩺 Sample 255 → Adjusted Prediction: Suspect
# 🩺 Sample 256 → Adjusted Prediction: Normal
# 🩺 Sample 257 → Adjusted Prediction: Suspect
# 🩺 Sample 258 → Adjusted Prediction: Pathological
# 🩺 Sample 259 → Adjusted Prediction: Suspect
# 🩺 Sample 260 → Adjusted Prediction: Pathological
# 🩺 Sample 261 → Adjusted Prediction: Pathological
# 🩺 Sample 262 → Adjusted Prediction: Normal
# 🩺 Sample 263 → Adjusted Prediction: Pathological
# 🩺 Sample 264 → Adjusted Prediction: Normal
# 🩺 Sample 265 → Adjusted Prediction: Normal
# 🩺 Sample 266 → Adjusted Prediction: Pathological
# 🩺 Sample 267 → Adjusted Prediction: Pathological
# 🩺 Sample 268 → Adjusted Prediction: Suspect
# 🩺 Sample 269 → Adjusted Prediction: Suspect
# 🩺 Sample 270 → Adjusted Prediction: Suspect
# 🩺 Sample 271 → Adjusted Prediction: Suspect
# 🩺 Sample 272 → Adjusted Prediction: Normal
# 🩺 Sample 273 → Adjusted Prediction: Suspect
# 🩺 Sample 274 → Adjusted Prediction: Normal
# 🩺 Sample 275 → Adjusted Prediction: Pathological
# 🩺 Sample 276 → Adjusted Prediction: Suspect
# 🩺 Sample 277 → Adjusted Prediction: Normal
# 🩺 Sample 278 → Adjusted Prediction: Suspect
# 🩺 Sample 279 → Adjusted Prediction: Normal
# 🩺 Sample 280 → Adjusted Prediction: Pathological
# 🩺 Sample 281 → Adjusted Prediction: Pathological
# 🩺 Sample 282 → Adjusted Prediction: Pathological
# 🩺 Sample 283 → Adjusted Prediction: Pathological
# 🩺 Sample 284 → Adjusted Prediction: Pathological
# 🩺 Sample 285 → Adjusted Prediction: Pathological
# 🩺 Sample 286 → Adjusted Prediction: Suspect
# 🩺 Sample 287 → Adjusted Prediction: Pathological
# 🩺 Sample 288 → Adjusted Prediction: Suspect
# 🩺 Sample 289 → Adjusted Prediction: Suspect
# 🩺 Sample 290 → Adjusted Prediction: Normal
# 🩺 Sample 291 → Adjusted Prediction: Normal
# 🩺 Sample 292 → Adjusted Prediction: Suspect
# 🩺 Sample 293 → Adjusted Prediction: Pathological
# 🩺 Sample 294 → Adjusted Prediction: Normal
# 🩺 Sample 295 → Adjusted Prediction: Suspect
# 🩺 Sample 296 → Adjusted Prediction: Suspect
# 🩺 Sample 297 → Adjusted Prediction: Suspect
# 🩺 Sample 298 → Adjusted Prediction: Suspect
# 🩺 Sample 299 → Adjusted Prediction: Pathological
# 🩺 Sample 300 → Adjusted Prediction: Normal
# 🩺 Sample 301 → Adjusted Prediction: Suspect
# 🩺 Sample 302 → Adjusted Prediction: Pathological
# 🩺 Sample 303 → Adjusted Prediction: Suspect
# 🩺 Sample 304 → Adjusted Prediction: Pathological
# 🩺 Sample 305 → Adjusted Prediction: Suspect
# 🩺 Sample 306 → Adjusted Prediction: Pathological
# 🩺 Sample 307 → Adjusted Prediction: Suspect
# 🩺 Sample 308 → Adjusted Prediction: Pathological
# 🩺 Sample 309 → Adjusted Prediction: Suspect
# 🩺 Sample 310 → Adjusted Prediction: Normal
# 🩺 Sample 311 → Adjusted Prediction: Pathological
# 🩺 Sample 312 → Adjusted Prediction: Pathological
# 🩺 Sample 313 → Adjusted Prediction: Pathological
# 🩺 Sample 314 → Adjusted Prediction: Pathological
# 🩺 Sample 315 → Adjusted Prediction: Suspect
# 🩺 Sample 316 → Adjusted Prediction: Pathological
# 🩺 Sample 317 → Adjusted Prediction: Suspect
# 🩺 Sample 318 → Adjusted Prediction: Normal
# 🩺 Sample 319 → Adjusted Prediction: Pathological
# 🩺 Sample 320 → Adjusted Prediction: Pathological
# 🩺 Sample 321 → Adjusted Prediction: Normal
# 🩺 Sample 322 → Adjusted Prediction: Normal
# 🩺 Sample 323 → Adjusted Prediction: Normal
# 🩺 Sample 324 → Adjusted Prediction: Suspect
# 🩺 Sample 325 → Adjusted Prediction: Suspect
# 🩺 Sample 326 → Adjusted Prediction: Suspect
# 🩺 Sample 327 → Adjusted Prediction: Suspect
# 🩺 Sample 328 → Adjusted Prediction: Normal
# 🩺 Sample 329 → Adjusted Prediction: Suspect
# 🩺 Sample 330 → Adjusted Prediction: Suspect
# 🩺 Sample 331 → Adjusted Prediction: Suspect
# 🩺 Sample 332 → Adjusted Prediction: Normal
# 🩺 Sample 333 → Adjusted Prediction: Suspect
# 🩺 Sample 334 → Adjusted Prediction: Pathological
# 🩺 Sample 335 → Adjusted Prediction: Suspect
# 🩺 Sample 336 → Adjusted Prediction: Pathological
# 🩺 Sample 337 → Adjusted Prediction: Suspect
# 🩺 Sample 338 → Adjusted Prediction: Pathological
# 🩺 Sample 339 → Adjusted Prediction: Normal
# 🩺 Sample 340 → Adjusted Prediction: Suspect
# 🩺 Sample 341 → Adjusted Prediction: Normal
# 🩺 Sample 342 → Adjusted Prediction: Pathological
# 🩺 Sample 343 → Adjusted Prediction: Pathological
# 🩺 Sample 344 → Adjusted Prediction: Normal
# 🩺 Sample 345 → Adjusted Prediction: Normal
# 🩺 Sample 346 → Adjusted Prediction: Suspect
# 🩺 Sample 347 → Adjusted Prediction: Pathological
# 🩺 Sample 348 → Adjusted Prediction: Pathological
# 🩺 Sample 349 → Adjusted Prediction: Normal
# 🩺 Sample 350 → Adjusted Prediction: Normal
# 🩺 Sample 351 → Adjusted Prediction: Pathological
# 🩺 Sample 352 → Adjusted Prediction: Normal
# 🩺 Sample 353 → Adjusted Prediction: Normal
# 🩺 Sample 354 → Adjusted Prediction: Suspect
# 🩺 Sample 355 → Adjusted Prediction: Suspect
# 🩺 Sample 356 → Adjusted Prediction: Suspect
# 🩺 Sample 357 → Adjusted Prediction: Suspect
# 🩺 Sample 358 → Adjusted Prediction: Normal
# 🩺 Sample 359 → Adjusted Prediction: Pathological
# 🩺 Sample 360 → Adjusted Prediction: Pathological
# 🩺 Sample 361 → Adjusted Prediction: Suspect
# 🩺 Sample 362 → Adjusted Prediction: Normal
# 🩺 Sample 363 → Adjusted Prediction: Suspect
# 🩺 Sample 364 → Adjusted Prediction: Normal
# 🩺 Sample 365 → Adjusted Prediction: Suspect
# 🩺 Sample 366 → Adjusted Prediction: Normal
# 🩺 Sample 367 → Adjusted Prediction: Normal
# 🩺 Sample 368 → Adjusted Prediction: Normal
# 🩺 Sample 369 → Adjusted Prediction: Normal
# 🩺 Sample 370 → Adjusted Prediction: Pathological
# 🩺 Sample 371 → Adjusted Prediction: Pathological
# 🩺 Sample 372 → Adjusted Prediction: Suspect
# 🩺 Sample 373 → Adjusted Prediction: Normal
# 🩺 Sample 374 → Adjusted Prediction: Normal
# 🩺 Sample 375 → Adjusted Prediction: Normal
# 🩺 Sample 376 → Adjusted Prediction: Normal
# 🩺 Sample 377 → Adjusted Prediction: Pathological
# 🩺 Sample 378 → Adjusted Prediction: Suspect
# 🩺 Sample 379 → Adjusted Prediction: Suspect
# 🩺 Sample 380 → Adjusted Prediction: Suspect
# 🩺 Sample 381 → Adjusted Prediction: Normal
# 🩺 Sample 382 → Adjusted Prediction: Normal
# 🩺 Sample 383 → Adjusted Prediction: Normal
# 🩺 Sample 384 → Adjusted Prediction: Suspect
# 🩺 Sample 385 → Adjusted Prediction: Pathological
# 🩺 Sample 386 → Adjusted Prediction: Pathological
# 🩺 Sample 387 → Adjusted Prediction: Normal
# 🩺 Sample 388 → Adjusted Prediction: Suspect
# 🩺 Sample 389 → Adjusted Prediction: Normal
# 🩺 Sample 390 → Adjusted Prediction: Suspect
# 🩺 Sample 391 → Adjusted Prediction: Suspect
# 🩺 Sample 392 → Adjusted Prediction: Normal
# 🩺 Sample 393 → Adjusted Prediction: Normal
# 🩺 Sample 394 → Adjusted Prediction: Suspect
# 🩺 Sample 395 → Adjusted Prediction: Pathological
# 🩺 Sample 396 → Adjusted Prediction: Suspect
# 🩺 Sample 397 → Adjusted Prediction: Pathological
# 🩺 Sample 398 → Adjusted Prediction: Pathological
# 🩺 Sample 399 → Adjusted Prediction: Normal
# 🩺 Sample 400 → Adjusted Prediction: Suspect
# 🩺 Sample 401 → Adjusted Prediction: Pathological
# 🩺 Sample 402 → Adjusted Prediction: Suspect
# 🩺 Sample 403 → Adjusted Prediction: Suspect
# 🩺 Sample 404 → Adjusted Prediction: Normal
# 🩺 Sample 405 → Adjusted Prediction: Pathological
# 🩺 Sample 406 → Adjusted Prediction: Normal
# 🩺 Sample 407 → Adjusted Prediction: Pathological
# 🩺 Sample 408 → Adjusted Prediction: Normal
# 🩺 Sample 409 → Adjusted Prediction: Pathological
# 🩺 Sample 410 → Adjusted Prediction: Normal
# 🩺 Sample 411 → Adjusted Prediction: Pathological
# 🩺 Sample 412 → Adjusted Prediction: Pathological
# 🩺 Sample 413 → Adjusted Prediction: Suspect
# 🩺 Sample 414 → Adjusted Prediction: Normal
# 🩺 Sample 415 → Adjusted Prediction: Suspect
# 🩺 Sample 416 → Adjusted Prediction: Suspect
# 🩺 Sample 417 → Adjusted Prediction: Normal
# 🩺 Sample 418 → Adjusted Prediction: Pathological
# 🩺 Sample 419 → Adjusted Prediction: Normal
# 🩺 Sample 420 → Adjusted Prediction: Normal
# 🩺 Sample 421 → Adjusted Prediction: Normal
# 🩺 Sample 422 → Adjusted Prediction: Pathological
# 🩺 Sample 423 → Adjusted Prediction: Suspect
# 🩺 Sample 424 → Adjusted Prediction: Suspect
# 🩺 Sample 425 → Adjusted Prediction: Suspect
# 🩺 Sample 426 → Adjusted Prediction: Pathological
# 🩺 Sample 427 → Adjusted Prediction: Normal
# 🩺 Sample 428 → Adjusted Prediction: Normal
# 🩺 Sample 429 → Adjusted Prediction: Normal
# 🩺 Sample 430 → Adjusted Prediction: Pathological
# 🩺 Sample 431 → Adjusted Prediction: Normal
# 🩺 Sample 432 → Adjusted Prediction: Suspect
# 🩺 Sample 433 → Adjusted Prediction: Normal
# 🩺 Sample 434 → Adjusted Prediction: Suspect
# 🩺 Sample 435 → Adjusted Prediction: Pathological
# 🩺 Sample 436 → Adjusted Prediction: Pathological
# 🩺 Sample 437 → Adjusted Prediction: Normal
# 🩺 Sample 438 → Adjusted Prediction: Pathological
# 🩺 Sample 439 → Adjusted Prediction: Suspect
# 🩺 Sample 440 → Adjusted Prediction: Suspect
# 🩺 Sample 441 → Adjusted Prediction: Pathological
# 🩺 Sample 442 → Adjusted Prediction: Normal
# 🩺 Sample 443 → Adjusted Prediction: Suspect
# 🩺 Sample 444 → Adjusted Prediction: Normal
# 🩺 Sample 445 → Adjusted Prediction: Suspect
# 🩺 Sample 446 → Adjusted Prediction: Normal
# 🩺 Sample 447 → Adjusted Prediction: Suspect
# 🩺 Sample 448 → Adjusted Prediction: Suspect
# 🩺 Sample 449 → Adjusted Prediction: Suspect
# 🩺 Sample 450 → Adjusted Prediction: Pathological
# 🩺 Sample 451 → Adjusted Prediction: Pathological
# 🩺 Sample 452 → Adjusted Prediction: Suspect
# 🩺 Sample 453 → Adjusted Prediction: Suspect
# 🩺 Sample 454 → Adjusted Prediction: Pathological
# 🩺 Sample 455 → Adjusted Prediction: Normal
# 🩺 Sample 456 → Adjusted Prediction: Pathological
# 🩺 Sample 457 → Adjusted Prediction: Suspect
# 🩺 Sample 458 → Adjusted Prediction: Suspect
# 🩺 Sample 459 → Adjusted Prediction: Suspect
# 🩺 Sample 460 → Adjusted Prediction: Normal
# 🩺 Sample 461 → Adjusted Prediction: Suspect
# 🩺 Sample 462 → Adjusted Prediction: Normal
# 🩺 Sample 463 → Adjusted Prediction: Suspect
# 🩺 Sample 464 → Adjusted Prediction: Suspect
# 🩺 Sample 465 → Adjusted Prediction: Pathological
# 🩺 Sample 466 → Adjusted Prediction: Suspect
# 🩺 Sample 467 → Adjusted Prediction: Pathological
# 🩺 Sample 468 → Adjusted Prediction: Pathological
# 🩺 Sample 469 → Adjusted Prediction: Normal
# 🩺 Sample 470 → Adjusted Prediction: Suspect
# 🩺 Sample 471 → Adjusted Prediction: Suspect
# 🩺 Sample 472 → Adjusted Prediction: Pathological
# 🩺 Sample 473 → Adjusted Prediction: Pathological
# 🩺 Sample 474 → Adjusted Prediction: Suspect
# 🩺 Sample 475 → Adjusted Prediction: Pathological
# 🩺 Sample 476 → Adjusted Prediction: Suspect
# 🩺 Sample 477 → Adjusted Prediction: Suspect
# 🩺 Sample 478 → Adjusted Prediction: Suspect
# 🩺 Sample 479 → Adjusted Prediction: Pathological
# 🩺 Sample 480 → Adjusted Prediction: Normal
# 🩺 Sample 481 → Adjusted Prediction: Normal
# 🩺 Sample 482 → Adjusted Prediction: Suspect
# 🩺 Sample 483 → Adjusted Prediction: Normal
# 🩺 Sample 484 → Adjusted Prediction: Normal
# 🩺 Sample 485 → Adjusted Prediction: Normal
# 🩺 Sample 486 → Adjusted Prediction: Suspect
# 🩺 Sample 487 → Adjusted Prediction: Normal
# 🩺 Sample 488 → Adjusted Prediction: Suspect
# 🩺 Sample 489 → Adjusted Prediction: Normal
# 🩺 Sample 490 → Adjusted Prediction: Normal
# 🩺 Sample 491 → Adjusted Prediction: Suspect
# 🩺 Sample 492 → Adjusted Prediction: Suspect
# 🩺 Sample 493 → Adjusted Prediction: Normal
# 🩺 Sample 494 → Adjusted Prediction: Normal
# 🩺 Sample 495 → Adjusted Prediction: Suspect
# 🩺 Sample 496 → Adjusted Prediction: Suspect
# 🩺 Sample 497 → Adjusted Prediction: Pathological
# 🩺 Sample 498 → Adjusted Prediction: Pathological
# 🩺 Sample 499 → Adjusted Prediction: Normal
# 🩺 Sample 500 → Adjusted Prediction: Normal
# 🩺 Sample 501 → Adjusted Prediction: Pathological
# 🩺 Sample 502 → Adjusted Prediction: Normal
# 🩺 Sample 503 → Adjusted Prediction: Suspect
# 🩺 Sample 504 → Adjusted Prediction: Normal
# 🩺 Sample 505 → Adjusted Prediction: Normal
# 🩺 Sample 506 → Adjusted Prediction: Normal
# 🩺 Sample 507 → Adjusted Prediction: Pathological
# 🩺 Sample 508 → Adjusted Prediction: Suspect
# 🩺 Sample 509 → Adjusted Prediction: Pathological
# 🩺 Sample 510 → Adjusted Prediction: Pathological
# 🩺 Sample 511 → Adjusted Prediction: Pathological
# 🩺 Sample 512 → Adjusted Prediction: Normal
# 🩺 Sample 513 → Adjusted Prediction: Pathological
# 🩺 Sample 514 → Adjusted Prediction: Suspect
# 🩺 Sample 515 → Adjusted Prediction: Normal
# 🩺 Sample 516 → Adjusted Prediction: Pathological
# 🩺 Sample 517 → Adjusted Prediction: Suspect
# 🩺 Sample 518 → Adjusted Prediction: Pathological
# 🩺 Sample 519 → Adjusted Prediction: Suspect
# 🩺 Sample 520 → Adjusted Prediction: Normal
# 🩺 Sample 521 → Adjusted Prediction: Pathological
# 🩺 Sample 522 → Adjusted Prediction: Normal
# 🩺 Sample 523 → Adjusted Prediction: Suspect
# 🩺 Sample 524 → Adjusted Prediction: Pathological
# 🩺 Sample 525 → Adjusted Prediction: Pathological
# 🩺 Sample 526 → Adjusted Prediction: Normal
# 🩺 Sample 527 → Adjusted Prediction: Suspect
# 🩺 Sample 528 → Adjusted Prediction: Pathological
# 🩺 Sample 529 → Adjusted Prediction: Suspect
# 🩺 Sample 530 → Adjusted Prediction: Pathological
# 🩺 Sample 531 → Adjusted Prediction: Suspect
# 🩺 Sample 532 → Adjusted Prediction: Pathological
# 🩺 Sample 533 → Adjusted Prediction: Suspect
# 🩺 Sample 534 → Adjusted Prediction: Normal
# 🩺 Sample 535 → Adjusted Prediction: Normal
# 🩺 Sample 536 → Adjusted Prediction: Pathological
# 🩺 Sample 537 → Adjusted Prediction: Suspect
# 🩺 Sample 538 → Adjusted Prediction: Pathological
# 🩺 Sample 539 → Adjusted Prediction: Pathological
# 🩺 Sample 540 → Adjusted Prediction: Normal
# 🩺 Sample 541 → Adjusted Prediction: Suspect
# 🩺 Sample 542 → Adjusted Prediction: Suspect
# 🩺 Sample 543 → Adjusted Prediction: Pathological
# 🩺 Sample 544 → Adjusted Prediction: Suspect
# 🩺 Sample 545 → Adjusted Prediction: Normal
# 🩺 Sample 546 → Adjusted Prediction: Normal
# 🩺 Sample 547 → Adjusted Prediction: Normal
# 🩺 Sample 548 → Adjusted Prediction: Normal
# 🩺 Sample 549 → Adjusted Prediction: Normal
# 🩺 Sample 550 → Adjusted Prediction: Suspect
# 🩺 Sample 551 → Adjusted Prediction: Normal
# 🩺 Sample 552 → Adjusted Prediction: Normal
# 🩺 Sample 553 → Adjusted Prediction: Pathological
# 🩺 Sample 554 → Adjusted Prediction: Normal
# 🩺 Sample 555 → Adjusted Prediction: Pathological
# 🩺 Sample 556 → Adjusted Prediction: Pathological
# 🩺 Sample 557 → Adjusted Prediction: Normal
# 🩺 Sample 558 → Adjusted Prediction: Suspect
# 🩺 Sample 559 → Adjusted Prediction: Suspect
# 🩺 Sample 560 → Adjusted Prediction: Pathological
# 🩺 Sample 561 → Adjusted Prediction: Normal
# 🩺 Sample 562 → Adjusted Prediction: Suspect
# 🩺 Sample 563 → Adjusted Prediction: Normal
# 🩺 Sample 564 → Adjusted Prediction: Suspect
# 🩺 Sample 565 → Adjusted Prediction: Suspect
# 🩺 Sample 566 → Adjusted Prediction: Pathological
# 🩺 Sample 567 → Adjusted Prediction: Suspect
# 🩺 Sample 568 → Adjusted Prediction: Suspect
# 🩺 Sample 569 → Adjusted Prediction: Normal
# 🩺 Sample 570 → Adjusted Prediction: Suspect
# 🩺 Sample 571 → Adjusted Prediction: Suspect
# 🩺 Sample 572 → Adjusted Prediction: Suspect
# 🩺 Sample 573 → Adjusted Prediction: Suspect
# 🩺 Sample 574 → Adjusted Prediction: Suspect
# 🩺 Sample 575 → Adjusted Prediction: Normal
# 🩺 Sample 576 → Adjusted Prediction: Suspect
# 🩺 Sample 577 → Adjusted Prediction: Pathological
# 🩺 Sample 578 → Adjusted Prediction: Normal
# 🩺 Sample 579 → Adjusted Prediction: Normal
# 🩺 Sample 580 → Adjusted Prediction: Pathological
# 🩺 Sample 581 → Adjusted Prediction: Suspect
# 🩺 Sample 582 → Adjusted Prediction: Pathological
# 🩺 Sample 583 → Adjusted Prediction: Suspect
# 🩺 Sample 584 → Adjusted Prediction: Pathological
# 🩺 Sample 585 → Adjusted Prediction: Suspect
# 🩺 Sample 586 → Adjusted Prediction: Pathological
# 🩺 Sample 587 → Adjusted Prediction: Pathological
# 🩺 Sample 588 → Adjusted Prediction: Suspect
# 🩺 Sample 589 → Adjusted Prediction: Pathological
# 🩺 Sample 590 → Adjusted Prediction: Pathological
# 🩺 Sample 591 → Adjusted Prediction: Normal
# 🩺 Sample 592 → Adjusted Prediction: Suspect
# 🩺 Sample 593 → Adjusted Prediction: Pathological
# 🩺 Sample 594 → Adjusted Prediction: Normal
# 🩺 Sample 595 → Adjusted Prediction: Suspect
# 🩺 Sample 596 → Adjusted Prediction: Pathological
# 🩺 Sample 597 → Adjusted Prediction: Pathological
# 🩺 Sample 598 → Adjusted Prediction: Suspect
# 🩺 Sample 599 → Adjusted Prediction: Normal
# 🩺 Sample 600 → Adjusted Prediction: Normal
# 🩺 Sample 601 → Adjusted Prediction: Suspect
# 🩺 Sample 602 → Adjusted Prediction: Pathological
# 🩺 Sample 603 → Adjusted Prediction: Pathological
# 🩺 Sample 604 → Adjusted Prediction: Normal
# 🩺 Sample 605 → Adjusted Prediction: Pathological
# 🩺 Sample 606 → Adjusted Prediction: Suspect
# 🩺 Sample 607 → Adjusted Prediction: Pathological
# 🩺 Sample 608 → Adjusted Prediction: Normal
# 🩺 Sample 609 → Adjusted Prediction: Pathological
# 🩺 Sample 610 → Adjusted Prediction: Suspect
# 🩺 Sample 611 → Adjusted Prediction: Suspect
# 🩺 Sample 612 → Adjusted Prediction: Pathological
# 🩺 Sample 613 → Adjusted Prediction: Normal
# 🩺 Sample 614 → Adjusted Prediction: Suspect
# 🩺 Sample 615 → Adjusted Prediction: Pathological
# 🩺 Sample 616 → Adjusted Prediction: Pathological
# 🩺 Sample 617 → Adjusted Prediction: Normal
# 🩺 Sample 618 → Adjusted Prediction: Normal
# 🩺 Sample 619 → Adjusted Prediction: Pathological
# 🩺 Sample 620 → Adjusted Prediction: Pathological
# 🩺 Sample 621 → Adjusted Prediction: Suspect
# 🩺 Sample 622 → Adjusted Prediction: Suspect
# 🩺 Sample 623 → Adjusted Prediction: Pathological
# 🩺 Sample 624 → Adjusted Prediction: Normal
# 🩺 Sample 625 → Adjusted Prediction: Suspect
# 🩺 Sample 626 → Adjusted Prediction: Pathological
# 🩺 Sample 627 → Adjusted Prediction: Suspect
# 🩺 Sample 628 → Adjusted Prediction: Pathological
# 🩺 Sample 629 → Adjusted Prediction: Pathological
# 🩺 Sample 630 → Adjusted Prediction: Pathological
# 🩺 Sample 631 → Adjusted Prediction: Suspect
# 🩺 Sample 632 → Adjusted Prediction: Pathological
# 🩺 Sample 633 → Adjusted Prediction: Pathological
# 🩺 Sample 634 → Adjusted Prediction: Pathological
# 🩺 Sample 635 → Adjusted Prediction: Normal
# 🩺 Sample 636 → Adjusted Prediction: Pathological
# 🩺 Sample 637 → Adjusted Prediction: Normal
# 🩺 Sample 638 → Adjusted Prediction: Pathological
# 🩺 Sample 639 → Adjusted Prediction: Suspect
# 🩺 Sample 640 → Adjusted Prediction: Suspect
# 🩺 Sample 641 → Adjusted Prediction: Normal
# 🩺 Sample 642 → Adjusted Prediction: Pathological
# 🩺 Sample 643 → Adjusted Prediction: Normal
# 🩺 Sample 644 → Adjusted Prediction: Pathological
# 🩺 Sample 645 → Adjusted Prediction: Suspect
# 🩺 Sample 646 → Adjusted Prediction: Normal
# 🩺 Sample 647 → Adjusted Prediction: Pathological
# 🩺 Sample 648 → Adjusted Prediction: Suspect
# 🩺 Sample 649 → Adjusted Prediction: Normal
# 🩺 Sample 650 → Adjusted Prediction: Pathological
# 🩺 Sample 651 → Adjusted Prediction: Suspect
# 🩺 Sample 652 → Adjusted Prediction: Normal
# 🩺 Sample 653 → Adjusted Prediction: Normal
# 🩺 Sample 654 → Adjusted Prediction: Suspect
# 🩺 Sample 655 → Adjusted Prediction: Normal
# 🩺 Sample 656 → Adjusted Prediction: Suspect
# 🩺 Sample 657 → Adjusted Prediction: Pathological
# 🩺 Sample 658 → Adjusted Prediction: Normal
# 🩺 Sample 659 → Adjusted Prediction: Normal
# 🩺 Sample 660 → Adjusted Prediction: Normal
# 🩺 Sample 661 → Adjusted Prediction: Normal
# 🩺 Sample 662 → Adjusted Prediction: Normal
# 🩺 Sample 663 → Adjusted Prediction: Pathological
# 🩺 Sample 664 → Adjusted Prediction: Normal
# 🩺 Sample 665 → Adjusted Prediction: Pathological
# 🩺 Sample 666 → Adjusted Prediction: Suspect
# 🩺 Sample 667 → Adjusted Prediction: Normal
# 🩺 Sample 668 → Adjusted Prediction: Suspect
# 🩺 Sample 669 → Adjusted Prediction: Suspect
# 🩺 Sample 670 → Adjusted Prediction: Normal
# 🩺 Sample 671 → Adjusted Prediction: Normal
# 🩺 Sample 672 → Adjusted Prediction: Pathological
# 🩺 Sample 673 → Adjusted Prediction: Normal
# 🩺 Sample 674 → Adjusted Prediction: Normal
# 🩺 Sample 675 → Adjusted Prediction: Pathological
# 🩺 Sample 676 → Adjusted Prediction: Suspect
# 🩺 Sample 677 → Adjusted Prediction: Normal
# 🩺 Sample 678 → Adjusted Prediction: Suspect
# 🩺 Sample 679 → Adjusted Prediction: Suspect
# 🩺 Sample 680 → Adjusted Prediction: Pathological
# 🩺 Sample 681 → Adjusted Prediction: Normal
# 🩺 Sample 682 → Adjusted Prediction: Pathological
# 🩺 Sample 683 → Adjusted Prediction: Pathological
# 🩺 Sample 684 → Adjusted Prediction: Normal
# 🩺 Sample 685 → Adjusted Prediction: Suspect
# 🩺 Sample 686 → Adjusted Prediction: Normal
# 🩺 Sample 687 → Adjusted Prediction: Suspect
# 🩺 Sample 688 → Adjusted Prediction: Pathological
# 🩺 Sample 689 → Adjusted Prediction: Pathological
# 🩺 Sample 690 → Adjusted Prediction: Suspect
# 🩺 Sample 691 → Adjusted Prediction: Pathological
# 🩺 Sample 692 → Adjusted Prediction: Normal
# 🩺 Sample 693 → Adjusted Prediction: Pathological
# 🩺 Sample 694 → Adjusted Prediction: Suspect
# 🩺 Sample 695 → Adjusted Prediction: Suspect
# 🩺 Sample 696 → Adjusted Prediction: Suspect
# 🩺 Sample 697 → Adjusted Prediction: Suspect
# 🩺 Sample 698 → Adjusted Prediction: Normal
# 🩺 Sample 699 → Adjusted Prediction: Pathological
# 🩺 Sample 700 → Adjusted Prediction: Normal
# 🩺 Sample 701 → Adjusted Prediction: Suspect
# 🩺 Sample 702 → Adjusted Prediction: Suspect
# 🩺 Sample 703 → Adjusted Prediction: Suspect
# 🩺 Sample 704 → Adjusted Prediction: Pathological
# 🩺 Sample 705 → Adjusted Prediction: Normal
# 🩺 Sample 706 → Adjusted Prediction: Normal
# 🩺 Sample 707 → Adjusted Prediction: Normal
# 🩺 Sample 708 → Adjusted Prediction: Pathological
# 🩺 Sample 709 → Adjusted Prediction: Pathological
# 🩺 Sample 710 → Adjusted Prediction: Suspect
# 🩺 Sample 711 → Adjusted Prediction: Normal
# 🩺 Sample 712 → Adjusted Prediction: Pathological
# 🩺 Sample 713 → Adjusted Prediction: Pathological
# 🩺 Sample 714 → Adjusted Prediction: Pathological
# 🩺 Sample 715 → Adjusted Prediction: Normal
# 🩺 Sample 716 → Adjusted Prediction: Pathological
# 🩺 Sample 717 → Adjusted Prediction: Normal
# 🩺 Sample 718 → Adjusted Prediction: Suspect
# 🩺 Sample 719 → Adjusted Prediction: Suspect
# 🩺 Sample 720 → Adjusted Prediction: Pathological
# 🩺 Sample 721 → Adjusted Prediction: Pathological
# 🩺 Sample 722 → Adjusted Prediction: Suspect
# 🩺 Sample 723 → Adjusted Prediction: Pathological
# 🩺 Sample 724 → Adjusted Prediction: Suspect
# 🩺 Sample 725 → Adjusted Prediction: Normal
# 🩺 Sample 726 → Adjusted Prediction: Pathological
# 🩺 Sample 727 → Adjusted Prediction: Normal
# 🩺 Sample 728 → Adjusted Prediction: Pathological
# 🩺 Sample 729 → Adjusted Prediction: Normal
# 🩺 Sample 730 → Adjusted Prediction: Normal
# 🩺 Sample 731 → Adjusted Prediction: Pathological
# 🩺 Sample 732 → Adjusted Prediction: Suspect
# 🩺 Sample 733 → Adjusted Prediction: Pathological
# 🩺 Sample 734 → Adjusted Prediction: Pathological
# 🩺 Sample 735 → Adjusted Prediction: Suspect
# 🩺 Sample 736 → Adjusted Prediction: Suspect
# 🩺 Sample 737 → Adjusted Prediction: Pathological
# 🩺 Sample 738 → Adjusted Prediction: Pathological
# 🩺 Sample 739 → Adjusted Prediction: Suspect
# 🩺 Sample 740 → Adjusted Prediction: Suspect
# 🩺 Sample 741 → Adjusted Prediction: Normal
# 🩺 Sample 742 → Adjusted Prediction: Pathological
# 🩺 Sample 743 → Adjusted Prediction: Pathological
# 🩺 Sample 744 → Adjusted Prediction: Suspect
# 🩺 Sample 745 → Adjusted Prediction: Pathological
# 🩺 Sample 746 → Adjusted Prediction: Suspect
# 🩺 Sample 747 → Adjusted Prediction: Suspect
# 🩺 Sample 748 → Adjusted Prediction: Pathological
# 🩺 Sample 749 → Adjusted Prediction: Pathological
# 🩺 Sample 750 → Adjusted Prediction: Suspect
# 🩺 Sample 751 → Adjusted Prediction: Suspect
# 🩺 Sample 752 → Adjusted Prediction: Suspect
# 🩺 Sample 753 → Adjusted Prediction: Pathological
# 🩺 Sample 754 → Adjusted Prediction: Suspect
# 🩺 Sample 755 → Adjusted Prediction: Pathological
# 🩺 Sample 756 → Adjusted Prediction: Normal
# 🩺 Sample 757 → Adjusted Prediction: Suspect
# 🩺 Sample 758 → Adjusted Prediction: Suspect
# 🩺 Sample 759 → Adjusted Prediction: Suspect
# 🩺 Sample 760 → Adjusted Prediction: Suspect
# 🩺 Sample 761 → Adjusted Prediction: Normal
# 🩺 Sample 762 → Adjusted Prediction: Normal
# 🩺 Sample 763 → Adjusted Prediction: Normal
# 🩺 Sample 764 → Adjusted Prediction: Suspect
# 🩺 Sample 765 → Adjusted Prediction: Suspect
# 🩺 Sample 766 → Adjusted Prediction: Normal
# 🩺 Sample 767 → Adjusted Prediction: Normal
# 🩺 Sample 768 → Adjusted Prediction: Pathological
# 🩺 Sample 769 → Adjusted Prediction: Normal
# 🩺 Sample 770 → Adjusted Prediction: Pathological
# 🩺 Sample 771 → Adjusted Prediction: Pathological
# 🩺 Sample 772 → Adjusted Prediction: Pathological
# 🩺 Sample 773 → Adjusted Prediction: Normal
# 🩺 Sample 774 → Adjusted Prediction: Suspect
# 🩺 Sample 775 → Adjusted Prediction: Pathological
# 🩺 Sample 776 → Adjusted Prediction: Pathological
# 🩺 Sample 777 → Adjusted Prediction: Suspect
# 🩺 Sample 778 → Adjusted Prediction: Pathological
# 🩺 Sample 779 → Adjusted Prediction: Pathological
# 🩺 Sample 780 → Adjusted Prediction: Pathological
# 🩺 Sample 781 → Adjusted Prediction: Suspect
# 🩺 Sample 782 → Adjusted Prediction: Suspect
# 🩺 Sample 783 → Adjusted Prediction: Suspect
# 🩺 Sample 784 → Adjusted Prediction: Suspect
# 🩺 Sample 785 → Adjusted Prediction: Suspect
# 🩺 Sample 786 → Adjusted Prediction: Suspect
# 🩺 Sample 787 → Adjusted Prediction: Pathological
# 🩺 Sample 788 → Adjusted Prediction: Suspect
# 🩺 Sample 789 → Adjusted Prediction: Normal
# 🩺 Sample 790 → Adjusted Prediction: Pathological
# 🩺 Sample 791 → Adjusted Prediction: Normal
# 🩺 Sample 792 → Adjusted Prediction: Suspect
# 🩺 Sample 793 → Adjusted Prediction: Suspect
# 🩺 Sample 794 → Adjusted Prediction: Suspect
# 🩺 Sample 795 → Adjusted Prediction: Suspect
# 🩺 Sample 796 → Adjusted Prediction: Suspect
# 🩺 Sample 797 → Adjusted Prediction: Suspect
# 🩺 Sample 798 → Adjusted Prediction: Suspect
# 🩺 Sample 799 → Adjusted Prediction: Normal
# 🩺 Sample 800 → Adjusted Prediction: Pathological
# 🩺 Sample 801 → Adjusted Prediction: Normal
# 🩺 Sample 802 → Adjusted Prediction: Normal
# 🩺 Sample 803 → Adjusted Prediction: Suspect
# 🩺 Sample 804 → Adjusted Prediction: Normal
# 🩺 Sample 805 → Adjusted Prediction: Normal
# 🩺 Sample 806 → Adjusted Prediction: Suspect
# 🩺 Sample 807 → Adjusted Prediction: Suspect
# 🩺 Sample 808 → Adjusted Prediction: Suspect
# 🩺 Sample 809 → Adjusted Prediction: Pathological
# 🩺 Sample 810 → Adjusted Prediction: Pathological
# 🩺 Sample 811 → Adjusted Prediction: Pathological
# 🩺 Sample 812 → Adjusted Prediction: Suspect
# 🩺 Sample 813 → Adjusted Prediction: Pathological
# 🩺 Sample 814 → Adjusted Prediction: Pathological
# 🩺 Sample 815 → Adjusted Prediction: Suspect
# 🩺 Sample 816 → Adjusted Prediction: Normal
# 🩺 Sample 817 → Adjusted Prediction: Suspect
# 🩺 Sample 818 → Adjusted Prediction: Normal
# 🩺 Sample 819 → Adjusted Prediction: Suspect
# 🩺 Sample 820 → Adjusted Prediction: Suspect
# 🩺 Sample 821 → Adjusted Prediction: Suspect
# 🩺 Sample 822 → Adjusted Prediction: Suspect
# 🩺 Sample 823 → Adjusted Prediction: Normal
# 🩺 Sample 824 → Adjusted Prediction: Pathological
# 🩺 Sample 825 → Adjusted Prediction: Suspect
# 🩺 Sample 826 → Adjusted Prediction: Suspect
# 🩺 Sample 827 → Adjusted Prediction: Normal
# 🩺 Sample 828 → Adjusted Prediction: Normal
# 🩺 Sample 829 → Adjusted Prediction: Normal
# 🩺 Sample 830 → Adjusted Prediction: Normal
# 🩺 Sample 831 → Adjusted Prediction: Pathological
# 🩺 Sample 832 → Adjusted Prediction: Normal
# 🩺 Sample 833 → Adjusted Prediction: Normal
# 🩺 Sample 834 → Adjusted Prediction: Normal
# 🩺 Sample 835 → Adjusted Prediction: Suspect
# 🩺 Sample 836 → Adjusted Prediction: Normal
# 🩺 Sample 837 → Adjusted Prediction: Normal
# 🩺 Sample 838 → Adjusted Prediction: Suspect
# 🩺 Sample 839 → Adjusted Prediction: Suspect
# 🩺 Sample 840 → Adjusted Prediction: Normal
# 🩺 Sample 841 → Adjusted Prediction: Suspect
# 🩺 Sample 842 → Adjusted Prediction: Suspect
# 🩺 Sample 843 → Adjusted Prediction: Pathological
# 🩺 Sample 844 → Adjusted Prediction: Pathological
# 🩺 Sample 845 → Adjusted Prediction: Pathological
# 🩺 Sample 846 → Adjusted Prediction: Normal
# 🩺 Sample 847 → Adjusted Prediction: Normal
# 🩺 Sample 848 → Adjusted Prediction: Pathological
# 🩺 Sample 849 → Adjusted Prediction: Pathological
# 🩺 Sample 850 → Adjusted Prediction: Normal
# 🩺 Sample 851 → Adjusted Prediction: Pathological
# 🩺 Sample 852 → Adjusted Prediction: Pathological
# 🩺 Sample 853 → Adjusted Prediction: Pathological
# 🩺 Sample 854 → Adjusted Prediction: Pathological
# 🩺 Sample 855 → Adjusted Prediction: Normal
# 🩺 Sample 856 → Adjusted Prediction: Pathological
# 🩺 Sample 857 → Adjusted Prediction: Pathological
# 🩺 Sample 858 → Adjusted Prediction: Normal
# 🩺 Sample 859 → Adjusted Prediction: Normal
# 🩺 Sample 860 → Adjusted Prediction: Pathological
# 🩺 Sample 861 → Adjusted Prediction: Normal
# 🩺 Sample 862 → Adjusted Prediction: Normal
# 🩺 Sample 863 → Adjusted Prediction: Normal
# 🩺 Sample 864 → Adjusted Prediction: Normal
# 🩺 Sample 865 → Adjusted Prediction: Suspect
# 🩺 Sample 866 → Adjusted Prediction: Normal
# 🩺 Sample 867 → Adjusted Prediction: Suspect
# 🩺 Sample 868 → Adjusted Prediction: Normal
# 🩺 Sample 869 → Adjusted Prediction: Pathological
# 🩺 Sample 870 → Adjusted Prediction: Suspect
# 🩺 Sample 871 → Adjusted Prediction: Normal
# 🩺 Sample 872 → Adjusted Prediction: Normal
# 🩺 Sample 873 → Adjusted Prediction: Pathological
# 🩺 Sample 874 → Adjusted Prediction: Pathological
# 🩺 Sample 875 → Adjusted Prediction: Suspect
# 🩺 Sample 876 → Adjusted Prediction: Suspect
# 🩺 Sample 877 → Adjusted Prediction: Normal
# 🩺 Sample 878 → Adjusted Prediction: Pathological
# 🩺 Sample 879 → Adjusted Prediction: Pathological
# 🩺 Sample 880 → Adjusted Prediction: Suspect
# 🩺 Sample 881 → Adjusted Prediction: Pathological
# 🩺 Sample 882 → Adjusted Prediction: Pathological
# 🩺 Sample 883 → Adjusted Prediction: Pathological
# 🩺 Sample 884 → Adjusted Prediction: Normal
# 🩺 Sample 885 → Adjusted Prediction: Pathological
# 🩺 Sample 886 → Adjusted Prediction: Pathological
# 🩺 Sample 887 → Adjusted Prediction: Normal
# 🩺 Sample 888 → Adjusted Prediction: Normal
# 🩺 Sample 889 → Adjusted Prediction: Normal
# 🩺 Sample 890 → Adjusted Prediction: Pathological
# 🩺 Sample 891 → Adjusted Prediction: Suspect
# 🩺 Sample 892 → Adjusted Prediction: Suspect
# 🩺 Sample 893 → Adjusted Prediction: Normal
# 🩺 Sample 894 → Adjusted Prediction: Normal
# 🩺 Sample 895 → Adjusted Prediction: Suspect
# 🩺 Sample 896 → Adjusted Prediction: Pathological
# 🩺 Sample 897 → Adjusted Prediction: Pathological
# 🩺 Sample 898 → Adjusted Prediction: Pathological
# 🩺 Sample 899 → Adjusted Prediction: Pathological
# 🩺 Sample 900 → Adjusted Prediction: Pathological
# 🩺 Sample 901 → Adjusted Prediction: Normal
# 🩺 Sample 902 → Adjusted Prediction: Pathological
# 🩺 Sample 903 → Adjusted Prediction: Normal
# 🩺 Sample 904 → Adjusted Prediction: Normal
# 🩺 Sample 905 → Adjusted Prediction: Pathological
# 🩺 Sample 906 → Adjusted Prediction: Suspect
# 🩺 Sample 907 → Adjusted Prediction: Normal
# 🩺 Sample 908 → Adjusted Prediction: Suspect
# 🩺 Sample 909 → Adjusted Prediction: Pathological
# 🩺 Sample 910 → Adjusted Prediction: Normal
# 🩺 Sample 911 → Adjusted Prediction: Suspect
# 🩺 Sample 912 → Adjusted Prediction: Pathological
# 🩺 Sample 913 → Adjusted Prediction: Suspect
# 🩺 Sample 914 → Adjusted Prediction: Normal
# 🩺 Sample 915 → Adjusted Prediction: Pathological
# 🩺 Sample 916 → Adjusted Prediction: Normal
# 🩺 Sample 917 → Adjusted Prediction: Pathological
# 🩺 Sample 918 → Adjusted Prediction: Normal
# 🩺 Sample 919 → Adjusted Prediction: Normal
# 🩺 Sample 920 → Adjusted Prediction: Suspect
# 🩺 Sample 921 → Adjusted Prediction: Suspect
# 🩺 Sample 922 → Adjusted Prediction: Pathological
# 🩺 Sample 923 → Adjusted Prediction: Normal
# 🩺 Sample 924 → Adjusted Prediction: Normal
# 🩺 Sample 925 → Adjusted Prediction: Pathological
# 🩺 Sample 926 → Adjusted Prediction: Normal
# 🩺 Sample 927 → Adjusted Prediction: Normal
# 🩺 Sample 928 → Adjusted Prediction: Pathological
# 🩺 Sample 929 → Adjusted Prediction: Normal
# 🩺 Sample 930 → Adjusted Prediction: Suspect
# 🩺 Sample 931 → Adjusted Prediction: Suspect
# 🩺 Sample 932 → Adjusted Prediction: Pathological
# 🩺 Sample 933 → Adjusted Prediction: Pathological
# 🩺 Sample 934 → Adjusted Prediction: Suspect
# 🩺 Sample 935 → Adjusted Prediction: Suspect
# 🩺 Sample 936 → Adjusted Prediction: Normal
# 🩺 Sample 937 → Adjusted Prediction: Pathological
# 🩺 Sample 938 → Adjusted Prediction: Normal
# 🩺 Sample 939 → Adjusted Prediction: Suspect
# 🩺 Sample 940 → Adjusted Prediction: Normal
# 🩺 Sample 941 → Adjusted Prediction: Pathological
# 🩺 Sample 942 → Adjusted Prediction: Normal
# 🩺 Sample 943 → Adjusted Prediction: Suspect
# 🩺 Sample 944 → Adjusted Prediction: Pathological
# 🩺 Sample 945 → Adjusted Prediction: Normal
# 🩺 Sample 946 → Adjusted Prediction: Pathological
# 🩺 Sample 947 → Adjusted Prediction: Suspect
# 🩺 Sample 948 → Adjusted Prediction: Suspect
# 🩺 Sample 949 → Adjusted Prediction: Suspect
# 🩺 Sample 950 → Adjusted Prediction: Pathological
# 🩺 Sample 951 → Adjusted Prediction: Suspect
# 🩺 Sample 952 → Adjusted Prediction: Pathological
# 🩺 Sample 953 → Adjusted Prediction: Suspect
# 🩺 Sample 954 → Adjusted Prediction: Suspect
# 🩺 Sample 955 → Adjusted Prediction: Normal
# 🩺 Sample 956 → Adjusted Prediction: Pathological
# 🩺 Sample 957 → Adjusted Prediction: Pathological
# 🩺 Sample 958 → Adjusted Prediction: Pathological
# 🩺 Sample 959 → Adjusted Prediction: Normal
# 🩺 Sample 960 → Adjusted Prediction: Pathological
# 🩺 Sample 961 → Adjusted Prediction: Suspect
# 🩺 Sample 962 → Adjusted Prediction: Suspect
# 🩺 Sample 963 → Adjusted Prediction: Normal
# 🩺 Sample 964 → Adjusted Prediction: Normal
# 🩺 Sample 965 → Adjusted Prediction: Normal
# 🩺 Sample 966 → Adjusted Prediction: Normal
# 🩺 Sample 967 → Adjusted Prediction: Normal
# 🩺 Sample 968 → Adjusted Prediction: Normal
# 🩺 Sample 969 → Adjusted Prediction: Normal
# 🩺 Sample 970 → Adjusted Prediction: Normal
# 🩺 Sample 971 → Adjusted Prediction: Suspect
# 🩺 Sample 972 → Adjusted Prediction: Normal
# 🩺 Sample 973 → Adjusted Prediction: Suspect
# 🩺 Sample 974 → Adjusted Prediction: Suspect
# 🩺 Sample 975 → Adjusted Prediction: Normal
# 🩺 Sample 976 → Adjusted Prediction: Pathological
# 🩺 Sample 977 → Adjusted Prediction: Suspect
# 🩺 Sample 978 → Adjusted Prediction: Suspect
# 🩺 Sample 979 → Adjusted Prediction: Pathological
# 🩺 Sample 980 → Adjusted Prediction: Suspect
# 🩺 Sample 981 → Adjusted Prediction: Suspect
# 🩺 Sample 982 → Adjusted Prediction: Pathological
# 🩺 Sample 983 → Adjusted Prediction: Pathological
# 🩺 Sample 984 → Adjusted Prediction: Pathological
# 🩺 Sample 985 → Adjusted Prediction: Suspect
# 🩺 Sample 986 → Adjusted Prediction: Normal
# 🩺 Sample 987 → Adjusted Prediction: Pathological
# 🩺 Sample 988 → Adjusted Prediction: Suspect
# 🩺 Sample 989 → Adjusted Prediction: Normal
# 🩺 Sample 990 → Adjusted Prediction: Suspect
# 🩺 Sample 991 → Adjusted Prediction: Pathological
# 🩺 Sample 992 → Adjusted Prediction: Pathological
# 🩺 Sample 993 → Adjusted Prediction: Suspect

# %% [markdown]
# # Visualizing Predictions with a Probability Bar Chart

# %%
import numpy as np
import matplotlib.pyplot as plt

# 🔹 Select 10 random test samples
num_samples = 10
random_indices = np.random.choice(len(X_test), num_samples, replace=False)
test_samples = X_test[random_indices]

# 🔹 Get Prediction Probabilities for Real Test Data
y_probs_test = stacking_clf_high.predict_proba(test_samples)

# 🔹 Adjust Probability Thresholds for Classification
threshold_suspect = 0.18  # Adjusted for better suspect detection
threshold_pathological = 0.10  # Lowered to better classify pathological cases

adjusted_preds_test = []
for prob in y_probs_test:
    if prob[2] >= threshold_pathological:  # If "Pathological" probability is high enough
        adjusted_preds_test.append(3)  # Pathological
    elif prob[1] >= threshold_suspect:  # If "Suspect" probability is high enough
        adjusted_preds_test.append(2)  # Suspect
    else:
        adjusted_preds_test.append(1)  # Normal

# 🔹 Define label mapping
health_conditions = {1: "Normal", 2: "Suspect", 3: "Pathological"}

# 🔹 Plot Probability Distribution for Each Sample
plt.figure(figsize=(12, 6))
for i, probs in enumerate(y_probs_test):
    plt.bar(["Normal", "Suspect", "Pathological"], probs, alpha=0.7, label=f"Sample {i+1}")

plt.xlabel("Fetal Health Condition")
plt.ylabel("Prediction Probability")
plt.title("Probability Distribution for 10 Random Test Samples")
plt.legend()
plt.show()

# 🔹 Print Adjusted Predictions for Real Test Data
print("\n Adjusted Predictions for Real Test Data:")
for i, pred in enumerate(adjusted_preds_test):
    print(f" Test Sample {i+1} → Adjusted Prediction: {health_conditions[pred]}")
# Out:
#  Adjusted Predictions for Real Test Data:
#  Test Sample 1 → Adjusted Prediction: Pathological
#  Test Sample 2 → Adjusted Prediction: Pathological
#  Test Sample 3 → Adjusted Prediction: Suspect
#  Test Sample 4 → Adjusted Prediction: Normal
#  Test Sample 5 → Adjusted Prediction: Suspect
#  Test Sample 6 → Adjusted Prediction: Suspect
#  Test Sample 7 → Adjusted Prediction: Suspect
#  Test Sample 8 → Adjusted Prediction: Normal
#  Test Sample 9 → Adjusted Prediction: Pathological
#  Test Sample 10 → Adjusted Prediction: Normal

# %% [markdown]
# # Confusion Matrices of Multiple Models

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# List of models to compare
models = {
    "Stacking Classifier (High-Performance)": stacking_clf_high,
    "LightGBM": lgb_model,
    "Logistic Regression": log_model,
    "Naïve Bayes": nb_model
}

# Define class labels
class_labels = [1, 2, 3]  # Corresponding to Normal, Suspect, Pathological

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Loop through models and generate confusion matrices
for idx, (name, model) in enumerate(models.items()):
    y_pred = model.predict(X_test)  # Make predictions
    cm = confusion_matrix(y_test, y_pred)  # Compute confusion matrix

    # Plot confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels, ax=axes[idx])
    axes[idx].set_title(name)
    axes[idx].set_xlabel("Predicted Label")
    axes[idx].set_ylabel("True Label")

# Adjust layout and display
plt.tight_layout()
plt.show()
